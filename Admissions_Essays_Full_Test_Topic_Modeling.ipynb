# %% [markdown]
# # Analysing Admissions Essays: Unsupervised Approaches using scikit-learn
#
# This notbook is designed to analyze every admissions essay submitted to Berkeley in the 2014-2015 academic year using Topic Modeling in Pythons scikit-learn package.  It begins with two CSV files (UTF-8) each containing unique and correspondeing dummie ID's for each of the two essay prompts that year.  There are column headers.
#
# ### Personal Statement 1
# 1. Freshmen: Describe the world you come from — for example, your family, community or school — and tell us how your world has shaped your dreams and aspirations.
# 1. Transfers: What is your intended major? Discuss how your interest in the subject developed and describe any experience you have had in the field — such as volunteer work, internships and employment, participation in student organizations and activities — and what you have gained from your involvement.
#
# ### Personal Statement 2
# 1. Tell us about a personal quality, talent, accomplishment, contribution or experience that is important to you. What about this quality or accomplishment makes you proud, and how does it relate to the person you are?
#
# ### Outline
# 1. Import and view the data using Pandas
#   1. Import the data into a Pandas Dataframe
#   1. Lable the columns
#   1. Merge the dataframes
#   1. Review the Data
# 1. Explore the Data & Drop missing values
#   1. Are the ID's Unique?
#   2. Find Missing Data
#   1. Drop Missing Data
# 1. Pre-Processing the Essays
#   1. Cleaning the text and tokenizing
#   1. Remove Stopwords
#   1. Stem the Tokens
# 1. Creating a sample for testing
# 1. Creating the DTM: scikit-learn
#   1. CountVectorizer function
# 1. What can we do with a DTM?
# 1. Tf-idf scores
#   1. TfidfVectorizer function
# 1. Identifying Distinctive Words
#   1. Application: Identify distinctive words by genre
# 1. Uncovering patterns using LDA

# %% [markdown]
# ## 1. Import and view the data using Pandas
#
# First, we read our corpus, which is stored as a .csv file on our hard drive, into a Pandas dataframe.
#
# Note: Pandas is great for data munging and basic calculations because it's so easy to use, and its data structure is really intuitive. It's not memory efficient however, so you might quickly need to move away from it.

# %% [markdown]
# ### Import the data into a Pandas Dataframe

# %% [markdown]
# To get started, we need to import a few packages.

# %%
import pandas
import numpy

# %% [markdown]
# Next we can import the data from the CSV Pandas and begin our session.

# %%
#create dataframes called "df1" and "df2
df1 = pandas.read_csv("/Volumes/Extra Space/Google Drive/Scholarship/Writing Projects - Personal/Admissions Essays/Data/PS1_F16.csv", sep = ',', encoding = 'utf_8')
df2 = pandas.read_csv("/Volumes/Extra Space/Google Drive/Scholarship/Writing Projects - Personal/Admissions Essays/Data/PS2_F16.csv", sep = ',', encoding = 'utf_8')

# View the dataframe.
# Notice the metadata. The column "Personal Statement 1 (RETIRED)" contains our text of interest.
# You can move the hashtag to view the other dataframe.
df1
# df2
# Out:
#        ﻿"ApplyUC Application CPID"                         College  \
# 0                          3128896  College of Letters and Science
# 1                          3092833          College of Engineering
# 2                          3142974          College of Engineering
# 3                          3020517  College of Letters and Science
# 4                          3121294    College of Natural Resources
# 5                          3162551  College of Letters and Science
# 6                          3090215  College of Letters and Science
# 7                          3158702          College of Engineering
# 8                          3095465    College of Natural Resources
# 9                          3147750  College of Letters and Science
# 10                         3036137  College of Letters and Science
# 11                         3141678  College of Letters and Science
# 12                         3162364  College of Letters and Science
# 13                         3123069    College of Natural Resources
# 14                         3079536  College of Letters and Science
# 15                         3016488  College of Letters and Science
# 16                         3137797          College of Engineering
# 17                         3056976          College of Engineering
# 18                         3095466  College of Letters and Science
# 19                         3138338  College of Letters and Science
# 20                         3056175          College of Engineering
# 21                         3097991          College of Engineering
# 22                         3103507            College of Chemistry
# 23                         3140004  College of Letters and Science
# 24                         3003517  College of Letters and Science
# 25                         3121783  College of Letters and Science
# 26                         3023027  College of Letters and Science
# 27                         3124456  College of Letters and Science
# 28                         3080657  College of Letters and Science
# 29                         3129963    College of Natural Resources
# ...                            ...                             ...
# 82544                      3018012    College of Natural Resources
# 82545                      3089703  College of Letters and Science
# 82546                      3060044  College of Letters and Science
# 82547                      3113335  College of Letters and Science
# 82548                      3068464  College of Letters and Science
# 82549                      3058267  College of Letters and Science
# 82550                      3049122          College of Engineering
# 82551                      3012260  College of Letters and Science
# 82552                      3134945  College of Letters and Science
# 82553                      3020998  College of Letters and Science
# 82554                      3084069  College of Letters and Science
# 82555                      3146928  College of Letters and Science
# 82556                      3077098  College of Letters and Science
# 82557                      3122721  College of Letters and Science
# 82558                      3147037  College of Letters and Science
# 82559                      3062729  College of Letters and Science
# 82560                      3160876  College of Letters and Science
# 82561                      3004237  College of Letters and Science
# 82562                      3000369  College of Letters and Science
# 82563                      3165291  College of Letters and Science
# 82564                      3029347            College of Chemistry
# 82565                      3126798  College of Letters and Science
# 82566                      3104291  College of Letters and Science
# 82567                      3081820  College of Letters and Science
# 82568                      3033185  College of Letters and Science
# 82569                      3066555  College of Letters and Science
# 82570                      3021099          College of Engineering
# 82571                      3057247  College of Letters and Science
# 82572                      3148270  College of Letters and Science
# 82573                      3039340  College of Letters and Science
#
#                           Personal Statement 1 (RETIRED)
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a 5' 10", lean man, who ...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of 15, one could very t...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November 2014, Tamir Rice, a twelve-year ol...
#
# [82574 rows x 3 columns]

# %% [markdown]
# ### Lable the Columns

# %% [markdown]
# Next we can rename the colum headers so they are easier to work with.

# %%
# This renames the colum headers
df1.columns = ['CPID', 'College', 'PS1']
df2.columns = ['CPID', 'College', 'PS2']

# View the dataframe.  You can move the hashtag to view the other dataframe.
df1
# df2
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# 19     3138338  College of Letters and Science
# 20     3056175          College of Engineering
# 21     3097991          College of Engineering
# 22     3103507            College of Chemistry
# 23     3140004  College of Letters and Science
# 24     3003517  College of Letters and Science
# 25     3121783  College of Letters and Science
# 26     3023027  College of Letters and Science
# 27     3124456  College of Letters and Science
# 28     3080657  College of Letters and Science
# 29     3129963    College of Natural Resources
# ...        ...                             ...
# 82544  3018012    College of Natural Resources
# 82545  3089703  College of Letters and Science
# 82546  3060044  College of Letters and Science
# 82547  3113335  College of Letters and Science
# 82548  3068464  College of Letters and Science
# 82549  3058267  College of Letters and Science
# 82550  3049122          College of Engineering
# 82551  3012260  College of Letters and Science
# 82552  3134945  College of Letters and Science
# 82553  3020998  College of Letters and Science
# 82554  3084069  College of Letters and Science
# 82555  3146928  College of Letters and Science
# 82556  3077098  College of Letters and Science
# 82557  3122721  College of Letters and Science
# 82558  3147037  College of Letters and Science
# 82559  3062729  College of Letters and Science
# 82560  3160876  College of Letters and Science
# 82561  3004237  College of Letters and Science
# 82562  3000369  College of Letters and Science
# 82563  3165291  College of Letters and Science
# 82564  3029347            College of Chemistry
# 82565  3126798  College of Letters and Science
# 82566  3104291  College of Letters and Science
# 82567  3081820  College of Letters and Science
# 82568  3033185  College of Letters and Science
# 82569  3066555  College of Letters and Science
# 82570  3021099          College of Engineering
# 82571  3057247  College of Letters and Science
# 82572  3148270  College of Letters and Science
# 82573  3039340  College of Letters and Science
#
#                                                      PS1
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a 5' 10", lean man, who ...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of 15, one could very t...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November 2014, Tamir Rice, a twelve-year ol...
#
# [82574 rows x 3 columns]

# %% [markdown]
# ### Merge the Dataframes

# %% [markdown]
# Now we will merge the two dataframes on thier two common elements (CPID and College) using `merge`.

# %%
# Merge the two data frames so that we have one data frame with both questions attached to common CPID's and College.
df = pandas.merge(df1, df2, on=['CPID', 'College'])
df
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# 19     3138338  College of Letters and Science
# 20     3056175          College of Engineering
# 21     3097991          College of Engineering
# 22     3103507            College of Chemistry
# 23     3140004  College of Letters and Science
# 24     3003517  College of Letters and Science
# 25     3121783  College of Letters and Science
# 26     3023027  College of Letters and Science
# 27     3124456  College of Letters and Science
# 28     3080657  College of Letters and Science
# 29     3129963    College of Natural Resources
# ...        ...                             ...
# 82544  3018012    College of Natural Resources
# 82545  3089703  College of Letters and Science
# 82546  3060044  College of Letters and Science
# 82547  3113335  College of Letters and Science
# 82548  3068464  College of Letters and Science
# 82549  3058267  College of Letters and Science
# 82550  3049122          College of Engineering
# 82551  3012260  College of Letters and Science
# 82552  3134945  College of Letters and Science
# 82553  3020998  College of Letters and Science
# 82554  3084069  College of Letters and Science
# 82555  3146928  College of Letters and Science
# 82556  3077098  College of Letters and Science
# 82557  3122721  College of Letters and Science
# 82558  3147037  College of Letters and Science
# 82559  3062729  College of Letters and Science
# 82560  3160876  College of Letters and Science
# 82561  3004237  College of Letters and Science
# 82562  3000369  College of Letters and Science
# 82563  3165291  College of Letters and Science
# 82564  3029347            College of Chemistry
# 82565  3126798  College of Letters and Science
# 82566  3104291  College of Letters and Science
# 82567  3081820  College of Letters and Science
# 82568  3033185  College of Letters and Science
# 82569  3066555  College of Letters and Science
# 82570  3021099          College of Engineering
# 82571  3057247  College of Letters and Science
# 82572  3148270  College of Letters and Science
# 82573  3039340  College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a 5' 10", lean man, who ...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of 15, one could very t...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November 2014, Tamir Rice, a twelve-year ol...
#
#                                                      PS2
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82544  When I was in the tenth grade, I accidentally ...
# 82545  Good communication skills can help us explore ...
# 82546  With other's respectful eyesight, I walked int...
# 82547  Efficiency overweighs meaningless efforts. Whe...
# 82548  I joined the swimming team in my community whe...
# 82549  When I really strain to remember my days as a ...
# 82550  As soon as I was introduced to Andy's illustri...
# 82551  It's open mic night at Busboys and Poets, and ...
# 82552  I believe the greatest attribute I possess is ...
# 82553  I try to be the kind of person that inspires o...
# 82554  Attaining the position of debate team captain ...
# 82555  It was summer 2012, and I was getting on a pla...
# 82556  A quality that I am proud to hold is that of a...
# 82557  There are many moments in our life that touch ...
# 82558  During first grade, instead of playing on the ...
# 82559  I've always cherished the first week of school...
# 82560  My life has taught me one quality that I value...
# 82561  One quality, or aspect if you may, about me th...
# 82562  In the summer of 2012, I traveled to the Peruv...
# 82563  Art is the foundation of how I interact with t...
# 82564  Ever since I can remember, I've been very clos...
# 82565  Sophomore year flew by and before I knew it I ...
# 82566  Community service has long been a part of my l...
# 82567  I went to the internship interview with all th...
# 82568  The pain started in my hands...Little did I kn...
# 82569  I am a hopeless romantic. A first kiss should ...
# 82570  If anyone had tried to tell me that a Facebook...
# 82571  In 2008, when I was 10 years old, my father sa...
# 82572  Throughout my high-school career, Model United...
# 82573  An experience during recovery from surgery dra...
#
# [82574 rows x 4 columns]

# %% [markdown]
# ### Review the data

# %% [markdown]
# It can be helpful to see how much memory is being used by this new dataframe.  We can do that with the `info` option.  We can also view individual essays, housed in particular cells, in full.

# %%
# Check the amount of memory being occupied by this newly created element.  
print(df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82574 entries, 0 to 82573
# Data columns (total 4 columns):
# CPID       82574 non-null int64
# College    82574 non-null object
# PS1        82544 non-null object
# PS2        82542 non-null object
# dtypes: int64(1), object(3)
# memory usage: 436.7 MB
# None

# %% [markdown]
# It is important to review data data that is contained in the new dataframe we created.  This code looks at an essay in full.

# %%
#print the first essay from the column 'PS1' the print file is more faithful to our data
print(df['PS1'][0])
# Out:
# Bojio!\\That was what I playfully typed on my family's Whatsapp group chat after my older brother posted a picture of his and my sister in law's Bali resort. It was an expression that travelled from my mind to my flitting fingertips almost immediately. The resort was simply the image of serenity and solitude- and which student going through examination stress would not want to be a part of that?\\It was only when I got home and slumped on the sofa that I saw the nervous look on my mother's face. Her kohl-rimmed eyes were wide and her vermillion adorned forehead scrunched up as she asked, utterly confused, "What's bojio?"\\I burst out laughing. Sometimes, I forgot how every day brought around a new culture shock when you lived in a traditional Indian family but grew up in a multiracial community. The Hokkien phrase "bojio", literally meaning "never invite", is a popular colloquialism in Singapore to teasingly express annoyance at not being invited to something. My brother, who has grown up in Singapore as well, would be familiar with it and probably retort with an impish reply making fun of my miserable situation. My parents, however, were dumbfounded.\\It was frustrating when I found it a challenge to explain this Hokkien phrase to my mother. I could tell her the definition, but not the feeling that came with it. So I illustrated it in a different context.\\"Mummy, how would you feel if you found out your best friends went to a cricket match without you?"\\She gasped.  For some Indians, not inviting your best friend to a cricket match is pretty much like not inviting them to your wedding.\\These experiences come daily when you speak not just two distinct languages, but a vibrant mix of many. Singlish is one of my favourite things about growing up in Singapore. I use Malay, Tamil, Mandarin and various other dialects regularly, sometimes without even realizing it. And with different languages come unique perspectives. When words like "sian", "lepak" and "shiok" roll off my tongue at home and I have to explain them, it is both slightly exasperating and extremely enlightening. It has made me realise language is a delightfully quirky part of culture, and I appreciate the diversity of communication that fills my life every day. It has made me respect and admire cultures, and made me sensitive to social nuances in an exceptional way.  \\The effects of my Indian upbringing also brim over to my experiences outside of home. Once, on Racial Harmony Day, I donned a traditional Indian salwar kameez and a bindi. My classmate asked what the dot on my forehead meant. It was not meant to be offensive, but I remember being taken aback. The bindi was anything but a mere dot. I recalled the trips my mother, aunts and I took to buy colourful bindis to give as presents to newly wedded women. The bindi was important to me, to my culture. But I could not explain why.\\I took it upon myself to ask my family members: my learned grandmothers, my upbeat aunts and some of my favourite cousins, but I never would have if I had not been questioned. It was a revelation indeed: perspective adds such astonishing complexity to everything. I found out that the bindi is not just cultural in meaning. There is a world of personal, religious and spiritual meaning behind it. From then on, I found myself hungry for multiple perspectives: be it articles about a political party or gossip about the newest relief teacher. \\I subsequently invited that classmate to a Diwali gathering at my house. Just then, my friend overheard us speaking and exclaimed, "Diwali bojio?!"\\I grinned at how my world resided in those two words.

# %% [markdown]
# ## 2. Explore the Data using Pandas
#
# Let's first evaluate the general nature of the data to see if the ID's are unique, if there is any missing data, etc.
# We can also look at some descriptive statistics about this data set to get a feel for what's in it. We'll do this using the Pandas package.
#
# Note: this is always good practice. It serves two purposes. It checks to make sure your data is correct, and there's no major errors. It also keeps you in touch with your data, which will help with interpretation. Love your data!

# %% [markdown]
# ### Are the ID's Unique?

# %% [markdown]
# What ID's have more than one "PS1"s can be found by counting and ranking "ID"s

# %%
#This tells us if we have any duplicate IDs.  If each response is 1 we are ok.
print(df['CPID'].value_counts())

# This code seems to check for duplicate CPIDs.  If it's blank there are no duplicates.
print()
print("Array containing duplicate CPIDs:")
print(df.set_index('CPID').index.get_duplicates())
# Out:
# 3016703    1
# 3002500    1
# 3146453    1
# 3152598    1
# 3019479    1
# 3042008    1
# 3039961    1
# 3018728    1
# 3035871    1
# 3123936    1
# 3125987    1
# 3115748    1
# 3030135    1
# 3117799    1
# 3009256    1
# 3013354    1
# 3130093    1
# 3136238    1
# 3003119    1
# 3027667    1
# 3029714    1
# 3068623    1
# 3056321    1
# 3084983    1
# 3107512    1
# 3105465    1
# 3109563    1
# 3103422    1
# 3101375    1
# 3058368    1
#           ..
# 3044772    1
# 3014037    1
# 3040678    1
# 3042727    1
# 3151272    1
# 3153321    1
# 3012128    1
# 3132004    1
# 3028396    1
# 3007894    1
# 3132819    1
# 3048826    1
# 3132755    1
# 3134800    1
# 3061116    1
# 3059071    1
# 3136223    1
# 3100035    1
# 3110276    1
# 3021600    1
# 3085704    1
# 3130770    1
# 3081610    1
# 3144558    1
# 3093900    1
# 3095949    1
# 3089806    1
# 3091855    1
# 3132125    1
# 3116651    1
# Name: CPID, dtype: int64
#
# Array containing duplicate CPIDs:
# []

# %% [markdown]
# ### Find missing essays

# %% [markdown]
# Advanced opperations will not work with empty data.  The next few steps are designed to find, exlpore and purge records with missing data.

# %%
# This creates a variable empties

# First for PS1
print('Summarizing missing data for PS1:')
empties_PS1 = numpy.where(pandas.isnull(df['PS1']))[0]

print(empties_PS1)

# you notice that this is not formatted as a list.  The next opperation "list" gets it in the right format.
empties_PS1 = list(empties_PS1)
print(empties_PS1)

#This counts the number of missing essays for PS1.
print(len(empties_PS1))

#This lists the elemtns with missing data.
df.iloc[empties_PS1]
# Out:
# Summarizing missing data for PS1:
# [ 1776  3206  3566  6285  6801  7530  7930  8111  8571 11796 12977 15694
#  19073 23667 24682 26014 28080 28573 29154 29548 31818 40212 41898 44980
#  53738 64612 73519 74177 79276 81423]
# [1776, 3206, 3566, 6285, 6801, 7530, 7930, 8111, 8571, 11796, 12977, 15694, 19073, 23667, 24682, 26014, 28080, 28573, 29154, 29548, 31818, 40212, 41898, 44980, 53738, 64612, 73519, 74177, 79276, 81423]
# 30
#           CPID                         College  PS1  \
# 1776   3133634          College of Engineering  NaN
# 3206   3157746  College of Letters and Science  NaN
# 3566   3041638  College of Letters and Science  NaN
# 6285   3108688    College of Natural Resources  NaN
# 6801   3052354  College of Letters and Science  NaN
# 7530   3055366  College of Letters and Science  NaN
# 7930   3056046          College of Engineering  NaN
# 8111   3001798  College of Letters and Science  NaN
# 8571   3145221    College of Natural Resources  NaN
# 11796  3092946  College of Letters and Science  NaN
# 12977  3119370  College of Letters and Science  NaN
# 15694  3069448    College of Natural Resources  NaN
# 19073  3111118  College of Letters and Science  NaN
# 23667  3002366  College of Letters and Science  NaN
# 24682  3017026  College of Letters and Science  NaN
# 26014  3127250  College of Letters and Science  NaN
# 28080  3102167  College of Letters and Science  NaN
# 28573  3062334  College of Letters and Science  NaN
# 29154  3148243    College of Natural Resources  NaN
# 29548  3130740  College of Letters and Science  NaN
# 31818  3103770  College of Letters and Science  NaN
# 40212  3153166  College of Letters and Science  NaN
# 41898  3092810  College of Letters and Science  NaN
# 44980  3085618  College of Letters and Science  NaN
# 53738  3068270  College of Letters and Science  NaN
# 64612  3127888  College of Letters and Science  NaN
# 73519  3065934  College of Letters and Science  NaN
# 74177  3123194  College of Letters and Science  NaN
# 79276  3084890  College of Letters and Science  NaN
# 81423  3062370  College of Letters and Science  NaN
#
#                                                      PS2
# 1776                                                 NaN
# 3206                                                 NaN
# 3566                                                 NaN
# 6285   I never described myself as super religious. W...
# 6801                                                 NaN
# 7530   At a young age the word "weird " or " differen...
# 7930                                                 NaN
# 8111                                                 NaN
# 8571   The ocean is my world. From an early age, the ...
# 11796                                                NaN
# 12977                                                NaN
# 15694  A personal accomplishment for me would have to...
# 19073                                                NaN
# 23667                                                NaN
# 24682                                                NaN
# 26014                                                NaN
# 28080  I was a freshman in high school when I first m...
# 28573                                                NaN
# 29154  Bicycling is the most meaningful sport in my l...
# 29548  The performance in an international art festiv...
# 31818                                                NaN
# 40212                                                NaN
# 41898                                                NaN
# 44980                                                NaN
# 53738                                                NaN
# 64612  It has been two years but I still remember the...
# 73519                                                NaN
# 74177                                                NaN
# 79276                                                NaN
# 81423                                                NaN

# %%
# Repeat the above steps for PS2
print('Summarizing missing data for PS2')
empties_PS2 = numpy.where(pandas.isnull(df['PS2']))[0]
print(empties_PS2)
empties_PS2 = list(empties_PS2)
print(empties_PS2)
print(len(empties_PS2))
df.iloc[empties_PS2]
# Out:
# Summarizing missing data for PS2
# [ 1222  1776  3206  3566  3667  3900  6801  7930  8111 11796 12977 14552
#  16926 19073 23667 24682 26014 28573 31818 36381 40212 41898 44980 53738
#  57647 60910 62127 72379 73519 74177 79276 81423]
# [1222, 1776, 3206, 3566, 3667, 3900, 6801, 7930, 8111, 11796, 12977, 14552, 16926, 19073, 23667, 24682, 26014, 28573, 31818, 36381, 40212, 41898, 44980, 53738, 57647, 60910, 62127, 72379, 73519, 74177, 79276, 81423]
# 32
#           CPID                         College  \
# 1222   3152303  College of Letters and Science
# 1776   3133634          College of Engineering
# 3206   3157746  College of Letters and Science
# 3566   3041638  College of Letters and Science
# 3667   3162451    College of Natural Resources
# 3900   3060413  College of Letters and Science
# 6801   3052354  College of Letters and Science
# 7930   3056046          College of Engineering
# 8111   3001798  College of Letters and Science
# 11796  3092946  College of Letters and Science
# 12977  3119370  College of Letters and Science
# 14552  3099420          College of Engineering
# 16926  3060549  College of Letters and Science
# 19073  3111118  College of Letters and Science
# 23667  3002366  College of Letters and Science
# 24682  3017026  College of Letters and Science
# 26014  3127250  College of Letters and Science
# 28573  3062334  College of Letters and Science
# 31818  3103770  College of Letters and Science
# 36381  3130479  College of Letters and Science
# 40212  3153166  College of Letters and Science
# 41898  3092810  College of Letters and Science
# 44980  3085618  College of Letters and Science
# 53738  3068270  College of Letters and Science
# 57647  3035190          College of Engineering
# 60910  3032050          College of Engineering
# 62127  3147560  College of Letters and Science
# 72379  3166337  College of Letters and Science
# 73519  3065934  College of Letters and Science
# 74177  3123194  College of Letters and Science
# 79276  3084890  College of Letters and Science
# 81423  3062370  College of Letters and Science
#
#                                                      PS1  PS2
# 1222   Every day, the mirror reminds me that I carry ...  NaN
# 1776                                                 NaN  NaN
# 3206                                                 NaN  NaN
# 3566                                                 NaN  NaN
# 3667   DAD'S BACK ACHED BECAUSE OF ME. Mom's hands mo...  NaN
# 3900   I am lying down on my belly, savoring the exqu...  NaN
# 6801                                                 NaN  NaN
# 7930                                                 NaN  NaN
# 8111                                                 NaN  NaN
# 11796                                                NaN  NaN
# 12977                                                NaN  NaN
# 14552  A Piece of My Life \The way I like to look at ...  NaN
# 16926  Since I started to remember things, science ha...  NaN
# 19073                                                NaN  NaN
# 23667                                                NaN  NaN
# 24682                                                NaN  NaN
# 26014                                                NaN  NaN
# 28573                                                NaN  NaN
# 31818                                                NaN  NaN
# 36381  Every Thursday I carry a bag of basketballs on...  NaN
# 40212                                                NaN  NaN
# 41898                                                NaN  NaN
# 44980                                                NaN  NaN
# 53738                                                NaN  NaN
# 57647  "We are visitors on this planet. We are here f...  NaN
# 60910  I must admit I come from very fortunate beginn...  NaN
# 62127  The Park School of Baltimore is a progressive ...  NaN
# 72379  LIFE IN THE SHADOW\\Life... Identity... Who Am...  NaN
# 73519                                                NaN  NaN
# 74177                                                NaN  NaN
# 79276                                                NaN  NaN
# 81423                                                NaN  NaN

# %% [markdown]
# Next we can create a list of every ID which has at least one missing essay.

# %%
#This combines the two lists of missing data without duplicateing anything.
empties_any = empties_PS1 + list(set(empties_PS2) - set(empties_PS1))
empties_any.sort()

print(empties_any)
print(len(empties_any))
# Out:
# [1222, 1776, 3206, 3566, 3667, 3900, 6285, 6801, 7530, 7930, 8111, 8571, 11796, 12977, 14552, 15694, 16926, 19073, 23667, 24682, 26014, 28080, 28573, 29154, 29548, 31818, 36381, 40212, 41898, 44980, 53738, 57647, 60910, 62127, 64612, 72379, 73519, 74177, 79276, 81423]
# 40

# %% [markdown]
# ### Drop the missing essays

# %% [markdown]
# This takes the list of ID's that have at least one missing essay and drops them, creating a new dataframe where each cell ID populated.

# %%
df_no_missing = df.drop(df.index[empties_any])

# df_no_missing = df.dropna()
df_no_missing
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# 19     3138338  College of Letters and Science
# 20     3056175          College of Engineering
# 21     3097991          College of Engineering
# 22     3103507            College of Chemistry
# 23     3140004  College of Letters and Science
# 24     3003517  College of Letters and Science
# 25     3121783  College of Letters and Science
# 26     3023027  College of Letters and Science
# 27     3124456  College of Letters and Science
# 28     3080657  College of Letters and Science
# 29     3129963    College of Natural Resources
# ...        ...                             ...
# 82544  3018012    College of Natural Resources
# 82545  3089703  College of Letters and Science
# 82546  3060044  College of Letters and Science
# 82547  3113335  College of Letters and Science
# 82548  3068464  College of Letters and Science
# 82549  3058267  College of Letters and Science
# 82550  3049122          College of Engineering
# 82551  3012260  College of Letters and Science
# 82552  3134945  College of Letters and Science
# 82553  3020998  College of Letters and Science
# 82554  3084069  College of Letters and Science
# 82555  3146928  College of Letters and Science
# 82556  3077098  College of Letters and Science
# 82557  3122721  College of Letters and Science
# 82558  3147037  College of Letters and Science
# 82559  3062729  College of Letters and Science
# 82560  3160876  College of Letters and Science
# 82561  3004237  College of Letters and Science
# 82562  3000369  College of Letters and Science
# 82563  3165291  College of Letters and Science
# 82564  3029347            College of Chemistry
# 82565  3126798  College of Letters and Science
# 82566  3104291  College of Letters and Science
# 82567  3081820  College of Letters and Science
# 82568  3033185  College of Letters and Science
# 82569  3066555  College of Letters and Science
# 82570  3021099          College of Engineering
# 82571  3057247  College of Letters and Science
# 82572  3148270  College of Letters and Science
# 82573  3039340  College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a 5' 10", lean man, who ...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of 15, one could very t...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November 2014, Tamir Rice, a twelve-year ol...
#
#                                                      PS2
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82544  When I was in the tenth grade, I accidentally ...
# 82545  Good communication skills can help us explore ...
# 82546  With other's respectful eyesight, I walked int...
# 82547  Efficiency overweighs meaningless efforts. Whe...
# 82548  I joined the swimming team in my community whe...
# 82549  When I really strain to remember my days as a ...
# 82550  As soon as I was introduced to Andy's illustri...
# 82551  It's open mic night at Busboys and Poets, and ...
# 82552  I believe the greatest attribute I possess is ...
# 82553  I try to be the kind of person that inspires o...
# 82554  Attaining the position of debate team captain ...
# 82555  It was summer 2012, and I was getting on a pla...
# 82556  A quality that I am proud to hold is that of a...
# 82557  There are many moments in our life that touch ...
# 82558  During first grade, instead of playing on the ...
# 82559  I've always cherished the first week of school...
# 82560  My life has taught me one quality that I value...
# 82561  One quality, or aspect if you may, about me th...
# 82562  In the summer of 2012, I traveled to the Peruv...
# 82563  Art is the foundation of how I interact with t...
# 82564  Ever since I can remember, I've been very clos...
# 82565  Sophomore year flew by and before I knew it I ...
# 82566  Community service has long been a part of my l...
# 82567  I went to the internship interview with all th...
# 82568  The pain started in my hands...Little did I kn...
# 82569  I am a hopeless romantic. A first kiss should ...
# 82570  If anyone had tried to tell me that a Facebook...
# 82571  In 2008, when I was 10 years old, my father sa...
# 82572  Throughout my high-school career, Model United...
# 82573  An experience during recovery from surgery dra...
#
# [82534 rows x 4 columns]

# %% [markdown]
# ## 3. Pre-Processing the Essays

# %% [markdown]
# Once we have a Pandas Dataframe in the appropreiate structure, we can begin to process the text in the two essay columns.  This invovles cleaning the text in a number of ways before tokenizing the essays.

# %% [markdown]
# ### Cleaning the text and tokenizing

# %% [markdown]
# The section below combines multiple preprocessing steps into a singl eline of code.  It is repeated twice for each of the essays, and results in a largely "preprocessed", tokenized new column.  most of this is accomplished with the "str" feature of python.  Here is what we accomplished with each step:
# 1. `str.replace('\\', ' ')` - This removes some of the ideosyncratic backslashes that were present
# 1. `str.lower()` - this shifts all the letters to lowercase
# 1. `str.replace('[^\w\s]','')` - This gets rid of punctuation.  The "`^`" is a negated set, the "`\w`" matches any word character (alphanumeric & underscore), and the "`\s`" matches any whitespace character (spaces, tabs, line breaks).
# 1. `str.replace('[\d]','')` - This gets rid of all numbers.
# 1. `str.split()` - This tokenizes whats left, creating a list within the pandas cell

# %%
#create two new columns with tokenized essay responses.  
#In the same opperation it make everything lowercase.
df_no_missing['PS1_tokens'] = df_no_missing['PS1'].str.replace('\\', ' ').str.lower().str.replace('[^\w\s]','').str.replace('[\d]','').str.split()
df_no_missing['PS2_tokens'] = df_no_missing['PS2'].str.replace('\\', ' ').str.lower().str.replace('[^\w\s]','').str.replace('[\d]','').str.split()
df_no_missing
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# 19     3138338  College of Letters and Science
# 20     3056175          College of Engineering
# 21     3097991          College of Engineering
# 22     3103507            College of Chemistry
# 23     3140004  College of Letters and Science
# 24     3003517  College of Letters and Science
# 25     3121783  College of Letters and Science
# 26     3023027  College of Letters and Science
# 27     3124456  College of Letters and Science
# 28     3080657  College of Letters and Science
# 29     3129963    College of Natural Resources
# ...        ...                             ...
# 82544  3018012    College of Natural Resources
# 82545  3089703  College of Letters and Science
# 82546  3060044  College of Letters and Science
# 82547  3113335  College of Letters and Science
# 82548  3068464  College of Letters and Science
# 82549  3058267  College of Letters and Science
# 82550  3049122          College of Engineering
# 82551  3012260  College of Letters and Science
# 82552  3134945  College of Letters and Science
# 82553  3020998  College of Letters and Science
# 82554  3084069  College of Letters and Science
# 82555  3146928  College of Letters and Science
# 82556  3077098  College of Letters and Science
# 82557  3122721  College of Letters and Science
# 82558  3147037  College of Letters and Science
# 82559  3062729  College of Letters and Science
# 82560  3160876  College of Letters and Science
# 82561  3004237  College of Letters and Science
# 82562  3000369  College of Letters and Science
# 82563  3165291  College of Letters and Science
# 82564  3029347            College of Chemistry
# 82565  3126798  College of Letters and Science
# 82566  3104291  College of Letters and Science
# 82567  3081820  College of Letters and Science
# 82568  3033185  College of Letters and Science
# 82569  3066555  College of Letters and Science
# 82570  3021099          College of Engineering
# 82571  3057247  College of Letters and Science
# 82572  3148270  College of Letters and Science
# 82573  3039340  College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a 5' 10", lean man, who ...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of 15, one could very t...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November 2014, Tamir Rice, a twelve-year ol...
#
#                                                      PS2  \
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82544  When I was in the tenth grade, I accidentally ...
# 82545  Good communication skills can help us explore ...
# 82546  With other's respectful eyesight, I walked int...
# 82547  Efficiency overweighs meaningless efforts. Whe...
# 82548  I joined the swimming team in my community whe...
# 82549  When I really strain to remember my days as a ...
# 82550  As soon as I was introduced to Andy's illustri...
# 82551  It's open mic night at Busboys and Poets, and ...
# 82552  I believe the greatest attribute I possess is ...
# 82553  I try to be the kind of person that inspires o...
# 82554  Attaining the position of debate team captain ...
# 82555  It was summer 2012, and I was getting on a pla...
# 82556  A quality that I am proud to hold is that of a...
# 82557  There are many moments in our life that touch ...
# 82558  During first grade, instead of playing on the ...
# 82559  I've always cherished the first week of school...
# 82560  My life has taught me one quality that I value...
# 82561  One quality, or aspect if you may, about me th...
# 82562  In the summer of 2012, I traveled to the Peruv...
# 82563  Art is the foundation of how I interact with t...
# 82564  Ever since I can remember, I've been very clos...
# 82565  Sophomore year flew by and before I knew it I ...
# 82566  Community service has long been a part of my l...
# 82567  I went to the internship interview with all th...
# 82568  The pain started in my hands...Little did I kn...
# 82569  I am a hopeless romantic. A first kiss should ...
# 82570  If anyone had tried to tell me that a Facebook...
# 82571  In 2008, when I was 10 years old, my father sa...
# 82572  Throughout my high-school career, Model United...
# 82573  An experience during recovery from surgery dra...
#
#                                               PS1_tokens  \
# 0      [bojio, that, was, what, i, playfully, typed, ...
# 1      [my, world, is, shaped, by, a, lean, man, who,...
# 2      [i, come, from, a, mediocre, family, in, malay...
# 3      [being, a, mexicanamerican, now, is, one, of, ...
# 4      [i, am, really, confused, when, i, have, to, f...
# 5      [since, before, i, was, born, my, parents, wan...
# 6      [when, i, think, of, my, cousin, sid, i, see, ...
# 7      [i, was, born, in, a, suburb, just, east, of, ...
# 8      [being, the, youngest, in, my, family, i, have...
# 9      [living, up, to, the, grand, expectations, of,...
# 10     [i, have, never, once, seen, my, parents, watc...
# 11     [above, all, else, my, family, is, adventurous...
# 12     [paper, shuffles, the, hum, of, the, engine, i...
# 13     [my, name, is, giovanni, aawar, im, american, ...
# 14     [growing, up, in, a, household, with, my, pare...
# 15     [living, in, the, impoverished, arlington, hei...
# 16     [brought, into, this, world, by, two, ethiopia...
# 17     [for, as, long, as, i, can, remember, ive, bee...
# 18     [i, have, come, to, value, hardships, in, life...
# 19     [i, come, from, a, world, of, glitter, feather...
# 20     [i, sat, in, the, dining, room, watching, the,...
# 21     [my, childhood, was, far, from, normal, imagin...
# 22     [this, isnt, what, i, expected, at, all, its, ...
# 23     [our, aspirations, are, shaped, by, our, envir...
# 24     [squad, my, squad, is, my, pride, of, lions, a...
# 25     [having, grown, up, in, an, ethiopian, home, m...
# 26     [i, live, in, an, environment, so, free, of, b...
# 27     [growing, up, i, was, greatly, influenced, by,...
# 28     [i, would, be, lying, if, i, said, that, movin...
# 29     [to, describe, the, world, i, come, from, i, w...
# ...                                                  ...
# 82544  [i, will, never, forget, the, day, i, saw, my,...
# 82545  [our, living, environment, often, subtly, infl...
# 82546  [having, the, parents, who, have, their, own, ...
# 82547  [my, family, my, junior, high, in, china, and,...
# 82548  [my, world, is, one, of, debate, and, activism...
# 82549  [a, biologist, would, suggest, i, have, one, s...
# 82550  [i, come, from, a, very, sciencefocused, famil...
# 82551  [im, fantastic, at, hideandseek, i, was, that,...
# 82552  [there, is, no, dignity, quite, so, impressive...
# 82553  [i, come, from, a, very, competitive, school, ...
# 82554  [dna, is, accepting, yet, judging, it, is, a, ...
# 82555  [i, come, from, something, i, like, to, call, ...
# 82556  [every, young, teen, has, his, or, her, own, d...
# 82557  [there, is, a, saying, one, is, alone, in, a, ...
# 82558  [my, world, is, full, of, adventure, excitemen...
# 82559  [exotic, i, tell, people, when, they, ask, my,...
# 82560  [my, world, until, the, age, of, one, could, v...
# 82561  [my, personal, life, has, followed, a, pattern...
# 82562  [since, my, freshman, year, i, have, been, par...
# 82563  [what, do, a, graphic, designer, an, astrophys...
# 82564  [when, she, first, came, to, america, my, moth...
# 82565  [i, understand, that, my, mother, was, a, craz...
# 82566  [one, of, the, best, parts, of, living, in, a,...
# 82567  [when, i, was, in, third, grade, my, family, m...
# 82568  [my, voice, is, my, identity, i, am, a, talker...
# 82569  [until, recently, i, hid, the, flaws, of, my, ...
# 82570  [a, group, that, i, am, very, involved, in, is...
# 82571  [i, stood, in, anticipation, as, my, opponent,...
# 82572  [it, was, more, than, a, drastic, change, in, ...
# 82573  [in, november, tamir, rice, a, twelveyear, old...
#
#                                               PS2_tokens
# 0      [costume, a, torn, and, tattered, shirt, and, ...
# 1      [since, childhood, i, have, yearned, for, utop...
# 2      [i, was, raised, in, a, family, where, academi...
# 3      [i, learned, about, the, female, stereotypes, ...
# 4      [the, bus, was, loud, and, smelled, it, did, n...
# 5      [in, the, past, when, i, wanted, information, ...
# 6      [theres, a, reason, that, people, buy, magazin...
# 7      [ive, had, a, few, defining, moments, througho...
# 8      [one, talent, that, i, am, proud, to, have, is...
# 9      [throughout, my, life, ive, explored, enjoyed,...
# 10     [from, the, ages, of, six, to, eight, i, kept,...
# 11     [one, experience, that, remains, exceptionally...
# 12     [my, high, school, experience, has, been, shap...
# 13     [selecting, a, profession, is, a, personal, de...
# 14     [on, every, second, day, of, the, academic, ye...
# 15     [at, the, beginning, of, eighth, grade, i, wok...
# 16     [i, began, playing, soccer, at, the, age, of, ...
# 17     [as, a, shy, th, grade, student, i, was, reluc...
# 18     [jumping, off, an, airplane, swimming, with, s...
# 19     [i, am, not, the, type, of, person, one, usual...
# 20     [allyson, has, just, won, king, of, the, lab, ...
# 21     [stepping, inside, my, mind, leads, to, a, tal...
# 22     [it, is, a, decision, that, forever, changed, ...
# 23     [i, knocked, on, the, door, i, had, recently, ...
# 24     [whats, an, intangible, improving, the, abilit...
# 25     [a, couple, years, ago, i, got, in, an, argume...
# 26     [through, school, and, my, participation, in, ...
# 27     [it, was, a, cool, summer, day, and, my, eccen...
# 28     [an, activity, ive, been, involved, in, since,...
# 29     [the, place, where, dreams, come, true, that, ...
# ...                                                  ...
# 82544  [when, i, was, in, the, tenth, grade, i, accid...
# 82545  [good, communication, skills, can, help, us, e...
# 82546  [with, others, respectful, eyesight, i, walked...
# 82547  [efficiency, overweighs, meaningless, efforts,...
# 82548  [i, joined, the, swimming, team, in, my, commu...
# 82549  [when, i, really, strain, to, remember, my, da...
# 82550  [as, soon, as, i, was, introduced, to, andys, ...
# 82551  [its, open, mic, night, at, busboys, and, poet...
# 82552  [i, believe, the, greatest, attribute, i, poss...
# 82553  [i, try, to, be, the, kind, of, person, that, ...
# 82554  [attaining, the, position, of, debate, team, c...
# 82555  [it, was, summer, and, i, was, getting, on, a,...
# 82556  [a, quality, that, i, am, proud, to, hold, is,...
# 82557  [there, are, many, moments, in, our, life, tha...
# 82558  [during, first, grade, instead, of, playing, o...
# 82559  [ive, always, cherished, the, first, week, of,...
# 82560  [my, life, has, taught, me, one, quality, that...
# 82561  [one, quality, or, aspect, if, you, may, about...
# 82562  [in, the, summer, of, i, traveled, to, the, pe...
# 82563  [art, is, the, foundation, of, how, i, interac...
# 82564  [ever, since, i, can, remember, ive, been, ver...
# 82565  [sophomore, year, flew, by, and, before, i, kn...
# 82566  [community, service, has, long, been, a, part,...
# 82567  [i, went, to, the, internship, interview, with...
# 82568  [the, pain, started, in, my, handslittle, did,...
# 82569  [i, am, a, hopeless, romantic, a, first, kiss,...
# 82570  [if, anyone, had, tried, to, tell, me, that, a...
# 82571  [in, when, i, was, years, old, my, father, sat...
# 82572  [throughout, my, highschool, career, model, un...
# 82573  [an, experience, during, recovery, from, surge...
#
# [82534 rows x 6 columns]

# %%
# this shows that we've mostly delt with the odd backslashes and cleand the text in a bunch of other ways!
print(df_no_missing['PS1_tokens'][0])
# Out:
# ['bojio', 'that', 'was', 'what', 'i', 'playfully', 'typed', 'on', 'my', 'familys', 'whatsapp', 'group', 'chat', 'after', 'my', 'older', 'brother', 'posted', 'a', 'picture', 'of', 'his', 'and', 'my', 'sister', 'in', 'laws', 'bali', 'resort', 'it', 'was', 'an', 'expression', 'that', 'travelled', 'from', 'my', 'mind', 'to', 'my', 'flitting', 'fingertips', 'almost', 'immediately', 'the', 'resort', 'was', 'simply', 'the', 'image', 'of', 'serenity', 'and', 'solitude', 'and', 'which', 'student', 'going', 'through', 'examination', 'stress', 'would', 'not', 'want', 'to', 'be', 'a', 'part', 'of', 'that', 'it', 'was', 'only', 'when', 'i', 'got', 'home', 'and', 'slumped', 'on', 'the', 'sofa', 'that', 'i', 'saw', 'the', 'nervous', 'look', 'on', 'my', 'mothers', 'face', 'her', 'kohlrimmed', 'eyes', 'were', 'wide', 'and', 'her', 'vermillion', 'adorned', 'forehead', 'scrunched', 'up', 'as', 'she', 'asked', 'utterly', 'confused', 'whats', 'bojio', 'i', 'burst', 'out', 'laughing', 'sometimes', 'i', 'forgot', 'how', 'every', 'day', 'brought', 'around', 'a', 'new', 'culture', 'shock', 'when', 'you', 'lived', 'in', 'a', 'traditional', 'indian', 'family', 'but', 'grew', 'up', 'in', 'a', 'multiracial', 'community', 'the', 'hokkien', 'phrase', 'bojio', 'literally', 'meaning', 'never', 'invite', 'is', 'a', 'popular', 'colloquialism', 'in', 'singapore', 'to', 'teasingly', 'express', 'annoyance', 'at', 'not', 'being', 'invited', 'to', 'something', 'my', 'brother', 'who', 'has', 'grown', 'up', 'in', 'singapore', 'as', 'well', 'would', 'be', 'familiar', 'with', 'it', 'and', 'probably', 'retort', 'with', 'an', 'impish', 'reply', 'making', 'fun', 'of', 'my', 'miserable', 'situation', 'my', 'parents', 'however', 'were', 'dumbfounded', 'it', 'was', 'frustrating', 'when', 'i', 'found', 'it', 'a', 'challenge', 'to', 'explain', 'this', 'hokkien', 'phrase', 'to', 'my', 'mother', 'i', 'could', 'tell', 'her', 'the', 'definition', 'but', 'not', 'the', 'feeling', 'that', 'came', 'with', 'it', 'so', 'i', 'illustrated', 'it', 'in', 'a', 'different', 'context', 'mummy', 'how', 'would', 'you', 'feel', 'if', 'you', 'found', 'out', 'your', 'best', 'friends', 'went', 'to', 'a', 'cricket', 'match', 'without', 'you', 'she', 'gasped', 'for', 'some', 'indians', 'not', 'inviting', 'your', 'best', 'friend', 'to', 'a', 'cricket', 'match', 'is', 'pretty', 'much', 'like', 'not', 'inviting', 'them', 'to', 'your', 'wedding', 'these', 'experiences', 'come', 'daily', 'when', 'you', 'speak', 'not', 'just', 'two', 'distinct', 'languages', 'but', 'a', 'vibrant', 'mix', 'of', 'many', 'singlish', 'is', 'one', 'of', 'my', 'favourite', 'things', 'about', 'growing', 'up', 'in', 'singapore', 'i', 'use', 'malay', 'tamil', 'mandarin', 'and', 'various', 'other', 'dialects', 'regularly', 'sometimes', 'without', 'even', 'realizing', 'it', 'and', 'with', 'different', 'languages', 'come', 'unique', 'perspectives', 'when', 'words', 'like', 'sian', 'lepak', 'and', 'shiok', 'roll', 'off', 'my', 'tongue', 'at', 'home', 'and', 'i', 'have', 'to', 'explain', 'them', 'it', 'is', 'both', 'slightly', 'exasperating', 'and', 'extremely', 'enlightening', 'it', 'has', 'made', 'me', 'realise', 'language', 'is', 'a', 'delightfully', 'quirky', 'part', 'of', 'culture', 'and', 'i', 'appreciate', 'the', 'diversity', 'of', 'communication', 'that', 'fills', 'my', 'life', 'every', 'day', 'it', 'has', 'made', 'me', 'respect', 'and', 'admire', 'cultures', 'and', 'made', 'me', 'sensitive', 'to', 'social', 'nuances', 'in', 'an', 'exceptional', 'way', 'the', 'effects', 'of', 'my', 'indian', 'upbringing', 'also', 'brim', 'over', 'to', 'my', 'experiences', 'outside', 'of', 'home', 'once', 'on', 'racial', 'harmony', 'day', 'i', 'donned', 'a', 'traditional', 'indian', 'salwar', 'kameez', 'and', 'a', 'bindi', 'my', 'classmate', 'asked', 'what', 'the', 'dot', 'on', 'my', 'forehead', 'meant', 'it', 'was', 'not', 'meant', 'to', 'be', 'offensive', 'but', 'i', 'remember', 'being', 'taken', 'aback', 'the', 'bindi', 'was', 'anything', 'but', ...

# %% [markdown]
# ### Remove Stopwords

# %% [markdown]
# Stopwords are  words that appear frequently and tend not to be distinctive.  They are generally removed prior to text analysis unless there is compelling reason to keep them. [More info](http://www.nltk.org/book/ch02.html#code-unusual)

# %%
#imports our list of stop words from NLTK
from nltk.corpus import stopwords

#Removes english stop words from the tokenized columns
stop_words = stopwords.words('english')
df_no_missing['PS1_tokens'] = df_no_missing['PS1_tokens'].apply(lambda x: [item for item in x if item not in stop_words])
df_no_missing['PS2_tokens'] = df_no_missing['PS2_tokens'].apply(lambda x: [item for item in x if item not in stop_words])

df_no_missing
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# 19     3138338  College of Letters and Science
# 20     3056175          College of Engineering
# 21     3097991          College of Engineering
# 22     3103507            College of Chemistry
# 23     3140004  College of Letters and Science
# 24     3003517  College of Letters and Science
# 25     3121783  College of Letters and Science
# 26     3023027  College of Letters and Science
# 27     3124456  College of Letters and Science
# 28     3080657  College of Letters and Science
# 29     3129963    College of Natural Resources
# ...        ...                             ...
# 82544  3018012    College of Natural Resources
# 82545  3089703  College of Letters and Science
# 82546  3060044  College of Letters and Science
# 82547  3113335  College of Letters and Science
# 82548  3068464  College of Letters and Science
# 82549  3058267  College of Letters and Science
# 82550  3049122          College of Engineering
# 82551  3012260  College of Letters and Science
# 82552  3134945  College of Letters and Science
# 82553  3020998  College of Letters and Science
# 82554  3084069  College of Letters and Science
# 82555  3146928  College of Letters and Science
# 82556  3077098  College of Letters and Science
# 82557  3122721  College of Letters and Science
# 82558  3147037  College of Letters and Science
# 82559  3062729  College of Letters and Science
# 82560  3160876  College of Letters and Science
# 82561  3004237  College of Letters and Science
# 82562  3000369  College of Letters and Science
# 82563  3165291  College of Letters and Science
# 82564  3029347            College of Chemistry
# 82565  3126798  College of Letters and Science
# 82566  3104291  College of Letters and Science
# 82567  3081820  College of Letters and Science
# 82568  3033185  College of Letters and Science
# 82569  3066555  College of Letters and Science
# 82570  3021099          College of Engineering
# 82571  3057247  College of Letters and Science
# 82572  3148270  College of Letters and Science
# 82573  3039340  College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a 5' 10", lean man, who ...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of 15, one could very t...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November 2014, Tamir Rice, a twelve-year ol...
#
#                                                      PS2  \
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82544  When I was in the tenth grade, I accidentally ...
# 82545  Good communication skills can help us explore ...
# 82546  With other's respectful eyesight, I walked int...
# 82547  Efficiency overweighs meaningless efforts. Whe...
# 82548  I joined the swimming team in my community whe...
# 82549  When I really strain to remember my days as a ...
# 82550  As soon as I was introduced to Andy's illustri...
# 82551  It's open mic night at Busboys and Poets, and ...
# 82552  I believe the greatest attribute I possess is ...
# 82553  I try to be the kind of person that inspires o...
# 82554  Attaining the position of debate team captain ...
# 82555  It was summer 2012, and I was getting on a pla...
# 82556  A quality that I am proud to hold is that of a...
# 82557  There are many moments in our life that touch ...
# 82558  During first grade, instead of playing on the ...
# 82559  I've always cherished the first week of school...
# 82560  My life has taught me one quality that I value...
# 82561  One quality, or aspect if you may, about me th...
# 82562  In the summer of 2012, I traveled to the Peruv...
# 82563  Art is the foundation of how I interact with t...
# 82564  Ever since I can remember, I've been very clos...
# 82565  Sophomore year flew by and before I knew it I ...
# 82566  Community service has long been a part of my l...
# 82567  I went to the internship interview with all th...
# 82568  The pain started in my hands...Little did I kn...
# 82569  I am a hopeless romantic. A first kiss should ...
# 82570  If anyone had tried to tell me that a Facebook...
# 82571  In 2008, when I was 10 years old, my father sa...
# 82572  Throughout my high-school career, Model United...
# 82573  An experience during recovery from surgery dra...
#
#                                               PS1_tokens  \
# 0      [bojio, playfully, typed, familys, whatsapp, g...
# 1      [world, shaped, lean, man, looks, like, despit...
# 2      [come, mediocre, family, malaysia, malaysian, ...
# 3      [mexicanamerican, one, amazing, things, could,...
# 4      [really, confused, fill, information, comes, s...
# 5      [since, born, parents, wanted, identify, dutch...
# 6      [think, cousin, sid, see, guy, loves, nascar, ...
# 7      [born, suburb, east, seattle, middle, class, f...
# 8      [youngest, family, held, much, higher, standar...
# 9      [living, grand, expectations, cardiologistprof...
# 10     [never, seen, parents, watch, sports, game, ki...
# 11     [else, family, adventurous, always, open, new,...
# 12     [paper, shuffles, hum, engine, heard, without,...
# 13     [name, giovanni, aawar, im, american, lebanese...
# 14     [growing, household, parents, siblings, made, ...
# 15     [living, impoverished, arlington, heights, sur...
# 16     [brought, world, two, ethiopian, nationals, mo...
# 17     [long, remember, ive, tinkerer, young, age, in...
# 18     [come, value, hardships, life, make, stronger,...
# 19     [come, world, glitter, feathers, crazy, patter...
# 20     [sat, dining, room, watching, chaotic, beauty,...
# 21     [childhood, far, normal, imagine, someone, lov...
# 22     [isnt, expected, convergence, two, worlds, six...
# 23     [aspirations, shaped, environment, well, impac...
# 24     [squad, squad, pride, lions, focused, accompli...
# 25     [grown, ethiopian, home, parents, strict, grad...
# 26     [live, environment, free, barriers, excel, bui...
# 27     [growing, greatly, influenced, parents, encour...
# 28     [would, lying, said, moving, america, happiest...
# 29     [describe, world, come, would, need, take, two...
# ...                                                  ...
# 82544  [never, forget, day, saw, classmates, throwing...
# 82545  [living, environment, often, subtly, influence...
# 82546  [parents, business, immersed, atmosphere, busi...
# 82547  [family, junior, high, china, senior, high, ca...
# 82548  [world, one, debate, activism, hold, interest,...
# 82549  [biologist, would, suggest, one, sibling, two,...
# 82550  [come, sciencefocused, family, garage, clutter...
# 82551  [im, fantastic, hideandseek, kid, birthday, pa...
# 82552  [dignity, quite, impressive, independence, qui...
# 82553  [come, competitive, school, carmel, high, scho...
# 82554  [dna, accepting, yet, judging, perfectly, logi...
# 82555  [come, something, like, call, limbo, community...
# 82556  [every, young, teen, dream, becomes, choice, m...
# 82557  [saying, one, alone, crowd, however, different...
# 82558  [world, full, adventure, excitement, encourage...
# 82559  [exotic, tell, people, ask, ethnicity, come, r...
# 82560  [world, age, one, could, truthfully, call, gil...
# 82561  [personal, life, followed, pattern, gradualism...
# 82562  [since, freshman, year, participating, weekly,...
# 82563  [graphic, designer, astrophysicist, elementary...
# 82564  [first, came, america, mother, worked, flower,...
# 82565  [understand, mother, crazy, youth, seeing, mak...
# 82566  [one, best, parts, living, large, family, wide...
# 82567  [third, grade, family, moved, new, york, londo...
# 82568  [voice, identity, talker, carrier, conversatio...
# 82569  [recently, hid, flaws, world, whether, lingeri...
# 82570  [group, involved, one, many, people, wouldnt, ...
# 82571  [stood, anticipation, opponent, rushed, toward...
# 82572  [drastic, change, scenery, fivehour, drive, we...
# 82573  [november, tamir, rice, twelveyear, old, livin...
#
#                                               PS2_tokens
# 0      [costume, torn, tattered, shirt, pants, old, c...
# 1      [since, childhood, yearned, utopia, know, appe...
# 2      [raised, family, academics, number, one, prior...
# 3      [learned, female, stereotypes, early, life, wo...
# 4      [bus, loud, smelled, help, ac, yellow, school,...
# 5      [past, wanted, information, inspiration, knew,...
# 6      [theres, reason, people, buy, magazines, want,...
# 7      [ive, defining, moments, throughout, life, cha...
# 8      [one, talent, proud, dancing, dancing, since, ...
# 9      [throughout, life, ive, explored, enjoyed, cha...
# 10     [ages, six, eight, kept, journal, sequence, nu...
# 11     [one, experience, remains, exceptionally, impo...
# 12     [high, school, experience, shaped, profoundly,...
# 13     [selecting, profession, personal, decision, ma...
# 14     [every, second, day, academic, year, school, c...
# 15     [beginning, eighth, grade, woke, first, day, s...
# 16     [began, playing, soccer, age, small, youth, le...
# 17     [shy, th, grade, student, reluctant, step, out...
# 18     [jumping, airplane, swimming, sharks, travelin...
# 19     [type, person, one, usually, finds, large, par...
# 20     [allyson, king, lab, chemistry, teacher, excla...
# 21     [stepping, inside, mind, leads, talent, long, ...
# 22     [decision, forever, changed, identity, age, tw...
# 23     [knocked, door, recently, attended, seminar, a...
# 24     [whats, intangible, improving, ability, improv...
# 25     [couple, years, ago, got, argument, best, frie...
# 26     [school, participation, community, found, base...
# 27     [cool, summer, day, eccentric, yearold, self, ...
# 28     [activity, ive, involved, since, th, grade, sp...
# 29     [place, dreams, come, true, slogan, disney, wo...
# ...                                                  ...
# 82544  [tenth, grade, accidentally, broke, two, front...
# 82545  [good, communication, skills, help, us, explor...
# 82546  [others, respectful, eyesight, walked, gym, tw...
# 82547  [efficiency, overweighs, meaningless, efforts,...
# 82548  [joined, swimming, team, community, seven, yea...
# 82549  [really, strain, remember, days, child, one, p...
# 82550  [soon, introduced, andys, illustrious, toy, bo...
# 82551  [open, mic, night, busboys, poets, despite, ho...
# 82552  [believe, greatest, attribute, possess, divers...
# 82553  [try, kind, person, inspires, others, want, le...
# 82554  [attaining, position, debate, team, captain, s...
# 82555  [summer, getting, plane, canada, anxiety, exci...
# 82556  [quality, proud, hold, leader, developed, stro...
# 82557  [many, moments, life, touch, us, way, shapes, ...
# 82558  [first, grade, instead, playing, monkey, bars,...
# 82559  [ive, always, cherished, first, week, school, ...
# 82560  [life, taught, one, quality, value, rest, pers...
# 82561  [one, quality, aspect, may, proud, natural, in...
# 82562  [summer, traveled, peruvian, amazon, rainfores...
# 82563  [art, foundation, interact, world, world, arou...
# 82564  [ever, since, remember, ive, close, grandfathe...
# 82565  [sophomore, year, flew, knew, racing, psra, ph...
# 82566  [community, service, long, part, life, vermont...
# 82567  [went, internship, interview, knowledge, thoug...
# 82568  [pain, started, handslittle, know, picked, mid...
# 82569  [hopeless, romantic, first, kiss, sweet, unfor...
# 82570  [anyone, tried, tell, facebook, post, would, i...
# 82571  [years, old, father, sat, formally, tell, goin...
# 82572  [throughout, highschool, career, model, united...
# 82573  [experience, recovery, surgery, dramatically, ...
#
# [82534 rows x 6 columns]

# %% [markdown]
# ### Stem the Tokens

# %% [markdown]
# Stemming reduces words with multiple endings to thier common stem.  There are multiple ways to do this, but we will use the Porter Stemmer for our purpouses.

# %%
# using the "Porter Stemmer" we'll stem the words
# from nltk.stem.porter import *
# stemmer = PorterStemmer()

# %% [markdown]
# ## 4. Creating a sample for testing
#
# In this section we'll create a smaller sample of the code to that the analysis we construct below works.

# %%
# This generates a random sample of N essays, with a random state set for reproducability.
# N can be slowly increased slowly to test the computational resources required as you scale up
df_sample = df_no_missing.sample(n=5000, random_state=0)

# This code resets the indexs so that sorted orininals are kept and new ones are generated.
df_sample = df_sample.sort_index()
df_sample = df_sample.reset_index()

df_sample
# Out:
#       index     CPID                          College  \
# 0        48  3140324   College of Letters and Science
# 1        51  3011169   College of Letters and Science
# 2        54  3059554   College of Letters and Science
# 3        56  3031745   College of Letters and Science
# 4        60  3060991   College of Letters and Science
# 5       128  3071955   College of Letters and Science
# 6       151  3104723     College of Natural Resources
# 7       166  3094246   College of Letters and Science
# 8       181  3130640   College of Letters and Science
# 9       213  3020042           College of Engineering
# 10      216  3061074   College of Letters and Science
# 11      275  3031283           College of Engineering
# 12      278  3136497   College of Letters and Science
# 13      281  3035030  College of Environmental Design
# 14      301  3040170           College of Engineering
# 15      302  3107375           College of Engineering
# 16      305  3014488   College of Letters and Science
# 17      321  3050718           College of Engineering
# 18      338  3163703     College of Natural Resources
# 19      366  3054490           College of Engineering
# 20      369  3107184   College of Letters and Science
# 21      372  3027609           College of Engineering
# 22      380  3116455           College of Engineering
# 23      382  3058336           College of Engineering
# 24      411  3158176   College of Letters and Science
# 25      413  3161110   College of Letters and Science
# 26      415  3093389   College of Letters and Science
# 27      439  3056579           College of Engineering
# 28      445  3012121   College of Letters and Science
# 29      464  3101780   College of Letters and Science
# ...     ...      ...                              ...
# 4970  82017  3160901   College of Letters and Science
# 4971  82022  3132984           College of Engineering
# 4972  82030  3059830   College of Letters and Science
# 4973  82045  3085496   College of Letters and Science
# 4974  82047  3131140           College of Engineering
# 4975  82059  3114994   College of Letters and Science
# 4976  82083  3153545   College of Letters and Science
# 4977  82105  3105641   College of Letters and Science
# 4978  82113  3069517             College of Chemistry
# 4979  82140  3089769   College of Letters and Science
# 4980  82177  3017772           College of Engineering
# 4981  82179  3064333     College of Natural Resources
# 4982  82186  3101524  College of Environmental Design
# 4983  82194  3088952     College of Natural Resources
# 4984  82225  3048440   College of Letters and Science
# 4985  82250  3005595   College of Letters and Science
# 4986  82338  3079504   College of Letters and Science
# 4987  82369  3136777   College of Letters and Science
# 4988  82430  3127173  College of Environmental Design
# 4989  82438  3157415   College of Letters and Science
# 4990  82442  3096371   College of Letters and Science
# 4991  82450  3056474   College of Letters and Science
# 4992  82486  3043657     College of Natural Resources
# 4993  82496  3073480   College of Letters and Science
# 4994  82529  3031930             College of Chemistry
# 4995  82530  3143242           College of Engineering
# 4996  82536  3114428           College of Engineering
# 4997  82559  3062729   College of Letters and Science
# 4998  82561  3004237   College of Letters and Science
# 4999  82562  3000369   College of Letters and Science
#
#                                                     PS1  \
# 0     I let out a deep sigh of disappointment when I...
# 1     I am from a family of 4, I am eldest son of th...
# 2     On the tiny desk in front of me, a yellow, pen...
# 3     The two people who have shaped me most are my ...
# 4     I easily have one of the most competitive fami...
# 5     It was the week of June 3, 2007 when I found o...
# 6     Despite prevailing opinions to the exact oppos...
# 7     "Good morning", I said. Eight pairs of eyes st...
# 8     It is strange how the social environment influ...
# 9     "Computers think and perform tasks like humans...
# 10    "Hey, you're the new kid, right? what's your n...
# 11    Throughout my childhood, I've lived in a lifes...
# 12    Within one day I went to two hospitals and tak...
# 13    I was born in a family who migrated to the Uni...
# 14    The language of mathematics is the same for ev...
# 15    I am Orock Achale Clinton, born on August 8th,...
# 16    My grandparents lived with us during my early ...
# 17    My family has influenced and shaped me tremend...
# 18    As I stared into the vulgar man's eyes, I felt...
# 19    There I was, sipping a cup of tea with mint an...
# 20    I have grown up in a pretty small classic subu...
# 21    Growing up playing soccer and getting good gra...
# 22    I have grown up in a home where medical and sc...
# 23    My Other Life\\Ever since I moved to America, ...
# 24    It was not that long ago when my mother, sibli...
# 25    The world I come from is a mosaic, broken and ...
# 26    Cape May: a mere 2.7 mile long beach resort at...
# 27    I come from an Indian family whose ancestry tr...
# 28    I'm not from a rich background  my dad left my...
# 29    At a young age, the wonders and realities of t...
# ...                                                 ...
# 4970  Every person is a distinctive world that summa...
# 4971  After the exhausting inter-galaxy journey, the...
# 4972  Since my 9th grade, I have been keeping regula...
# 4973  There's no dust in my grandfather's room. Ever...
# 4974  Colours and shapes have started to weave my ow...
# 4975  I owe as much to the world I came from as to t...
# 4976  China's culture, with its long history of stre...
# 4977  "At least I hadn't been to Boston before." I'v...
# 4978  Since the beginning of high school, I was engr...
# 4979  When I was younger I used to think the whole w...
# 4980  In classic role playing games (RPGs), there ar...
# 4981  When I sat in the theater and watched the high...
# 4982  During the architecture program at Cornell tha...
# 4983  My mother never needed a storybook. The tales ...
# 4984  To prepare for the school's upcoming Art Festi...
# 4985  To me, "Bookworm" is a term of endearment. I'm...
# 4986  In early spring 2012, when it was finally clea...
# 4987  "Wir schaffen das!", or in English "We will ma...
# 4988  What comes to mind when you see the words "inn...
# 4989  The family that I was born into is not by any ...
# 4990  I was sent to China for the first five years o...
# 4991  I belonged at the end of the alphabet- that wa...
# 4992  Walking down the avenue, countless constructio...
# 4993  I was born into a family devoting to stock inv...
# 4994  My parents always told me to stay away from ho...
# 4995  My life has been much different than most kids...
# 4996  I remember the screams of joy I delivered when...
# 4997  "Exotic," I tell people when they ask my ethni...
# 4998  My personal life has followed a pattern of gra...
# 4999  Since my freshman year, I have been participat...
#
#                                                     PS2
# 0     I stepped out of a decorated rickshaw only to ...
# 1     I want to be a better person, a person with gr...
# 2     I power off my phone, press my hand to the doo...
# 3     Stumbling through the park at lightning speed,...
# 4     Having gone through the troubles that I went t...
# 5     Giving back to my community has always been im...
# 6     For 13 years I think I hardly spoke a handful ...
# 7     Surrounded by mountains of canned goods, used ...
# 8     "Last Ketchup" is the first song I truly loved...
# 9     "The SAT is a test that you cannot study for b...
# 10    From the moment a baby puts a toy in his mouth...
# 11    Strength can be found in many places. It is a ...
# 12    Can you say someone threw a knife blade at you...
# 13    The best accomplishment I had was winning firs...
# 14    Imagine getting an education in a place where ...
# 15    I am constantly being reminded by my teachers ...
# 16    As I approached the Ronald McDonald House in P...
# 17    Two summers ago I wanted to earn some money. E...
# 18    Living in a society that praises women for the...
# 19    Pick a Card\\"Guys I'm leaving.  I'll be out o...
# 20    For most, growing up it seems as though the ha...
# 21    Standing at the peak of one of the tallest mou...
# 22    In October, ten top scientific minds from high...
# 23    ?During my 2015 spring break, my friends and I...
# 24    Fleeing back to the States has been an enlight...
# 25    The spring of my sophomore year I resolved to ...
# 26    At the measly age of two years old, my mother ...
# 27    My involvement in speech and debate has had a ...
# 28    One of the accomplishment I've accomplished is...
# 29    "Are you hungry?" Justin asked.\\It was a simp...
# ...                                                 ...
# 4970  I had always thought introversion was a proble...
# 4971  My friends have nicknamed me D.I.Y. because I ...
# 4972  It is Saturday evening. I am waiting for an em...
# 4973  "Never again will I ride the subway," I pledge...
# 4974  I bowed, face towards the ground, but the appl...
# 4975  I took the ceramics class last year for my gra...
# 4976  "Mom" was the first word my three special sibl...
# 4977  Weeks of drilling ourselves on the characteris...
# 4978  We often subconsciously feel that the grass is...
# 4979  ?I've loved writing since the day my hands wer...
# 4980  Eavesdropping is usually not an admirable acti...
# 4981  I woke up at 6 a.m., got dressed, and was read...
# 4982  I grew up in China, and I went to a small Chri...
# 4983  A bamboo dragonfly swooped upward and bumped i...
# 4984  As if it was like any other day at school in t...
# 4985  I wish it wasn't called a language barrier - t...
# 4986  I have been serving as volunteer in Chengdu Ch...
# 4987  I was recently given the opportunity to volunt...
# 4988  I find it hard to express the countless ways t...
# 4989  From a young age I always wanted to come to th...
# 4990  During junior year, I became depressed. There ...
# 4991  Recently, I volunteered at the OC Rescue Missi...
# 4992  It was in the healthcare centre for the elderl...
# 4993  The original aim was to expand my vision, my m...
# 4994  "How are you going to do the literature essays...
# 4995  My social abilities are what set me apart from...
# 4996  Looking outside my window, my eyes could only ...
# 4997  I've always cherished the first week of school...
# 4998  One quality, or aspect if you may, about me th...
# 4999  In the summer of 2012, I traveled to the Peruv...
#
# [5000 rows x 5 columns]

# %% [markdown]
# ## 5. Creating the DTM: scikit-learn
#
# Ok, that's the summary of the metadata. Next, we turn to analyzing the text of the reviews. Remember, the text is stored in the 'body' column. First, a preprocessing step to remove numbers.

# %%
# This gets rid of numbers - THIS SEEMS TO BREAK WITH MY DATA
# It appears that if you drop rows with missing data it works!
df_no_missing['PS1'] = df_no_missing['PS1'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))

# If this generates an error we might consider uncommeting code below to see the data type:
#df.dtypes

# %% [markdown]
# Our next step is to turn the text into a document term matrix using the scikit-learn function called CountVectorizer. There are two ways to do this. We can turn it into a sparse matrix type, which can be used within scikit-learn for further analyses.  We can then turn it into a full documnet term matrix, but this is very memory intensive and might not be a great idea for larger data sets.

# %%
#import the function CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

countvec = CountVectorizer()

# Original sklearn_dtm = CountVectorizer().fit_transform(df.PS1)
#I added the values.astype section below and it seemed to fix the count vectorizer issues
sklearn_dtm_PS1 = countvec.fit_transform(df_no_missing['PS1'].values.astype('U'))
sklearn_dtm_PS2 = countvec.fit_transform(df_no_missing['PS2'].values.astype('U'))

print('PS1 sparse matrix type')
print(sklearn_dtm_PS1)
print(' ')
print('PS2 sparse matrix type')
print(sklearn_dtm_PS2)
# Out:
# PS1 sparse matrix type
#   (0, 97510)	1
#   (0, 81381)	1
#   (0, 40180)	1
#   (0, 32375)	1
#   (0, 91071)	1
#   (0, 103386)	1
#   (0, 69831)	1
#   (0, 44425)	1
#   (0, 37706)	1
#   (0, 27054)	2
#   (0, 93627)	1
#   (0, 96220)	1
#   (0, 80697)	1
#   (0, 66015)	1
#   (0, 39472)	1
#   (0, 68854)	1
#   (0, 71276)	1
#   (0, 74705)	1
#   (0, 5479)	1
#   (0, 63986)	1
#   (0, 44915)	1
#   (0, 97200)	2
#   (0, 8902)	1
#   (0, 91376)	1
#   (0, 80711)	1
#   :	:
#   (82533, 106502)	3
#   (82533, 42907)	1
#   (82533, 43878)	1
#   (82533, 71195)	1
#   (82533, 8509)	3
#   (82533, 105761)	1
#   (82533, 67065)	1
#   (82533, 107860)	2
#   (82533, 97620)	1
#   (82533, 45997)	1
#   (82533, 97152)	19
#   (82533, 98284)	12
#   (82533, 36643)	3
#   (82533, 3577)	3
#   (82533, 49257)	3
#   (82533, 46552)	8
#   (82533, 3727)	8
#   (82533, 68009)	15
#   (82533, 68281)	1
#   (82533, 1747)	2
#   (82533, 64424)	13
#   (82533, 68478)	6
#   (82533, 106651)	3
#   (82533, 105895)	5
#   (82533, 97120)	2
#
# PS2 sparse matrix type
#   (0, 97850)	1
#   (0, 70837)	1
#   (0, 61668)	1
#   (0, 57872)	1
#   (0, 99832)	1
#   (0, 35958)	1
#   (0, 30585)	1
#   (0, 102252)	1
#   (0, 98749)	1
#   (0, 100003)	1
#   (0, 65910)	1
#   (0, 31065)	1
#   (0, 45778)	1
#   (0, 16093)	1
#   (0, 46419)	1
#   (0, 41208)	1
#   (0, 78260)	1
#   (0, 24892)	1
#   (0, 7331)	1
#   (0, 18604)	1
#   (0, 55893)	1
#   (0, 109273)	2
#   (0, 65338)	1
#   (0, 35035)	1
#   (0, 75916)	1
#   :	:
#   (82533, 65581)	1
#   (82533, 58528)	3
#   (82533, 110006)	4
#   (82533, 100806)	24
#   (82533, 99603)	6
#   (82533, 62609)	8
#   (82533, 38584)	8
#   (82533, 35461)	5
#   (82533, 11522)	1
#   (82533, 100117)	3
#   (82533, 43977)	1
#   (82533, 109468)	3
#   (82533, 39534)	5
#   (82533, 52189)	3
#   (82533, 110429)	5
#   (82533, 51416)	2
#   (82533, 66886)	24
#   (82533, 99944)	1
#   (82533, 59566)	3
#   (82533, 6338)	2
#   (82533, 70404)	17
#   (82533, 99631)	37
#   (82533, 69462)	1
#   (82533, 108442)	12
#   (82533, 6489)	10

# %% [markdown]
# This format is called Compressed Sparse Format. It save a lot of memory to store the dtm in this format, but it is difficult to look at for a human. To illustrate the techniques in this lesson we will first convert this matrix back to a Pandas dataframe, a format we're more familiar with. For larger datasets, you will have to use the Compressed Sparse Format. Putting it into a DataFrame, however, will enable us to get more comfortable with Pandas! For this data, we will skip this step to avoid crashing the kernal.

# %%
# #we do the same as we did above, but covert it into a Pandas dataframe. Note this takes quite a bit more memory, so will not be good for bigger data.
# dtm_df = pandas.DataFrame(countvec.fit_transform(df_sample['PS1'].values.astype('U')).toarray(), columns=countvec.get_feature_names(), index = df_sample.index)

# #view the dtm dataframe
# dtm_df

# %% [markdown]
# ## 6. What can we do with a DTM?
#
# We can do a number of calculations using a DTM. For a toy example, we can quickly identify the most frequent words (compare this to how many steps it took in lesson 2, where we found the most frequent words using NLTK).

# %%
print(dtm_df.sum().sort_values(ascending=False))
# print(dtm_df.sum().sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-e668a50c454b> in <module>()
# ----> 1 print(sklearn_dtm_PS1.sum().sort_values(ascending=False))
#       2 # print(dtm_df.sum().sort_values(ascending=False))
#
# AttributeError: 'numpy.int64' object has no attribute 'sort_values'

# %%
#####Exercise:
###Print out the most infrequent words rather than the most frequent words.
##Gold star challenge: print the average number of times each word is used in an essay
print(dtm_df.mean().sort_values(ascending=False))
#Print this out sorted from highest to lowest.

# %% [markdown]
# What else does the DTM enable? Because it is in the format of a matrix, we can perform any matrix algebra or vector manipulation on it, which enables some pretty exciting things (think vector space and Euclidean  geometry). But, what do we lose when we reprsent text in this format?
#
# Today, we will use variations on the DTM to find distinctive words in this dataset, and then do some preliminary work discovering themes in text.

# %% [markdown]
# ## 7. Tf-idf scores
#
# How to find distinctive words in a corpus is a long-standing question in text analysis. We saw a few ways to this yesterday, using natural language processing. Today, we'll learn one simple approach to this: word scores. The idea behind words scores is to weight words not just by their frequency, but by their frequency in one document compared to their distribution across all documents. Words that are frequent, but are also used in every single document, will not be distinguising. We want to identify words that are unevenly distributed across the corpus.
#
# One of the most popular ways to weight words (beyond frequency counts) is *tf-idf* scores. By offsetting the frequency of a word by its document frequency (the number of documents in which it appears) will in theory filter out common terms such as 'the', 'of', and 'and'.
#
# More precisely, the inverse document frequency is calculated as such:
#
# number_of_documents / number_documents_with_term
#
# so:
#
# tfidf_word1 = word1_frequency_document1 * (number_of_documents / number_document_with_word1)
#
# You can, and often should, normalize the numerator:
#
# tfidf_word1 = (word1_frequency_document1 / word_count_document1) * (number_of_documents / number_document_with_word1)
#
# We can calculate this manually, but scikit-learn has a built-in function to do so. We'll use it, but a challenge for you: use Pandas to calculate this manually.
#
# To do so, we simply do the same thing we did above with CountVectorizer, but instead we use the function TfidfVectorizer.

# %%
#import the function
from sklearn.feature_extraction.text import TfidfVectorizer

tfidfvec = TfidfVectorizer()

# #create the dtm, but with cells weigthed by the tf-idf score.
# dtm_tfidf_df = pandas.DataFrame(tfidfvec.fit_transform(df.PS1).toarray(), columns=tfidfvec.get_feature_names(), index = df.index)

# #view results
# dtm_tfidf_df

# %% [markdown]
# Let's look at the 20 words with highest tf-idf weights.

# %%
# print(dtm_tfidf_df.max().sort_values(ascending=False)[0:20])

# %% [markdown]
# ## 8. Uncovering Patterns: LDA
#
# Frequency counts and tf-idf scores are done at the word level. There are other methods of exporatory or unsupervised analysis on the document level and by examining the co-occurrence of words within documents. Scikit-learn allows for many of these methods, including:
#
# * document clustering
# * document or word similarities using cosine similarity
# * pca
# * topic modeling
#
# We'll run through an example of topic modeling here. Again, the goal is not to learn everything you need to know about topic modeling. Instead, this will provide you some starter code to run a simple model, with the idea that you can use this base of knowledge to explore this further.
#
# We will run Latent Dirichlet Allocation, the most basic and the oldest version of topic modeling. We will run this in one big chunk of code. Our challenge: use our knowledge of scikit-learn that we gained aboe to walk through the code to understand what it is doing. Your challenge: figure out how to modify this code to work on your own data, and/or tweak the parameters to get better output.
#
# Note: we will be using a different dataset for this technique. The music reviews in the above dataset are often short, one word or one sentence reviews. Topic modeling is not really appropriate for texts that are this short. Instead, we want texts that are longer and are composed of multiple topics each. For this exercise we will use a database of children's literature from the 19th century.
#
# The data were compiled by students in this course: http://english197s2015.pbworks.com/w/page/93127947/FrontPage
# Found here: http://dhresourcesforprojectbuilding.pbworks.com/w/page/69244469/Data%20Collections%20and%20Datasets#demo-corpora
#
# That page has additional corpora, for those interested in exploring text analysis further.
#
# I did some minimal cleaning to get the children's literature data in .csv format for our use.

# %%
# df_lit = pandas.read_csv("/Volumes/Extra Space/Google Drive/Scholarship/Writing Projects - Personal/Admissions Essays/Small Sample/AdmissionsEssays/statement_test_031417.csv", sep = ',', encoding = 'utf-8')

# #drop rows where the text is missing. I think there's only one row where it's missing, but check me on that.
# df_lit = df_lit.dropna(subset=['PS1'])

df_lit = df_no_missing

#view the dataframe
df_lit
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# 19     3138338  College of Letters and Science
# 20     3056175          College of Engineering
# 21     3097991          College of Engineering
# 22     3103507            College of Chemistry
# 23     3140004  College of Letters and Science
# 24     3003517  College of Letters and Science
# 25     3121783  College of Letters and Science
# 26     3023027  College of Letters and Science
# 27     3124456  College of Letters and Science
# 28     3080657  College of Letters and Science
# 29     3129963    College of Natural Resources
# ...        ...                             ...
# 82544  3018012    College of Natural Resources
# 82545  3089703  College of Letters and Science
# 82546  3060044  College of Letters and Science
# 82547  3113335  College of Letters and Science
# 82548  3068464  College of Letters and Science
# 82549  3058267  College of Letters and Science
# 82550  3049122          College of Engineering
# 82551  3012260  College of Letters and Science
# 82552  3134945  College of Letters and Science
# 82553  3020998  College of Letters and Science
# 82554  3084069  College of Letters and Science
# 82555  3146928  College of Letters and Science
# 82556  3077098  College of Letters and Science
# 82557  3122721  College of Letters and Science
# 82558  3147037  College of Letters and Science
# 82559  3062729  College of Letters and Science
# 82560  3160876  College of Letters and Science
# 82561  3004237  College of Letters and Science
# 82562  3000369  College of Letters and Science
# 82563  3165291  College of Letters and Science
# 82564  3029347            College of Chemistry
# 82565  3126798  College of Letters and Science
# 82566  3104291  College of Letters and Science
# 82567  3081820  College of Letters and Science
# 82568  3033185  College of Letters and Science
# 82569  3066555  College of Letters and Science
# 82570  3021099          College of Engineering
# 82571  3057247  College of Letters and Science
# 82572  3148270  College of Letters and Science
# 82573  3039340  College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a ' ", lean man, who loo...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82544  I will never forget the day I saw my classmate...
# 82545  Our living environment often subtly influences...
# 82546  Having the parents who have their own business...
# 82547  My family, my junior high in China and my seni...
# 82548  My world is one of debate and activism. They h...
# 82549  A biologist would suggest I have one sibling a...
# 82550  I come from a very science-focused family. Our...
# 82551  I'm fantastic at hide-and-seek. I was that kid...
# 82552  "There is no dignity quite so impressive, and ...
# 82553  I come from a very competitive school, Carmel ...
# 82554  DNA is accepting yet judging; it is a perfectl...
# 82555  I come from something I like to call the limbo...
# 82556  Every young teen has his or her own dream, but...
# 82557  There is a saying 'one is alone in a crowd', h...
# 82558  My world is full of adventure, excitement, enc...
# 82559  "Exotic," I tell people when they ask my ethni...
# 82560  My world until the age of , one could very tru...
# 82561  My personal life has followed a pattern of gra...
# 82562  Since my freshman year, I have been participat...
# 82563  What do a graphic designer, an astrophysicist,...
# 82564  When she first came to America, my mother work...
# 82565  I understand that my mother was a crazy youth,...
# 82566  One of the best parts of living in a large fam...
# 82567  When I was in third grade, my family moved fro...
# 82568  My voice is my identity. I am a talker: the ca...
# 82569  Until recently, I hid the flaws of my world. W...
# 82570  A group that I am very involved in is one that...
# 82571  I stood in anticipation as my opponent rushed ...
# 82572  It was more than a drastic change in scenery. ...
# 82573  In November , Tamir Rice, a twelve-year old li...
#
#                                                      PS2
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82544  When I was in the tenth grade, I accidentally ...
# 82545  Good communication skills can help us explore ...
# 82546  With other's respectful eyesight, I walked int...
# 82547  Efficiency overweighs meaningless efforts. Whe...
# 82548  I joined the swimming team in my community whe...
# 82549  When I really strain to remember my days as a ...
# 82550  As soon as I was introduced to Andy's illustri...
# 82551  It's open mic night at Busboys and Poets, and ...
# 82552  I believe the greatest attribute I possess is ...
# 82553  I try to be the kind of person that inspires o...
# 82554  Attaining the position of debate team captain ...
# 82555  It was summer 2012, and I was getting on a pla...
# 82556  A quality that I am proud to hold is that of a...
# 82557  There are many moments in our life that touch ...
# 82558  During first grade, instead of playing on the ...
# 82559  I've always cherished the first week of school...
# 82560  My life has taught me one quality that I value...
# 82561  One quality, or aspect if you may, about me th...
# 82562  In the summer of 2012, I traveled to the Peruv...
# 82563  Art is the foundation of how I interact with t...
# 82564  Ever since I can remember, I've been very clos...
# 82565  Sophomore year flew by and before I knew it I ...
# 82566  Community service has long been a part of my l...
# 82567  I went to the internship interview with all th...
# 82568  The pain started in my hands...Little did I kn...
# 82569  I am a hopeless romantic. A first kiss should ...
# 82570  If anyone had tried to tell me that a Facebook...
# 82571  In 2008, when I was 10 years old, my father sa...
# 82572  Throughout my high-school career, Model United...
# 82573  An experience during recovery from surgery dra...
#
# [82534 rows x 4 columns]

# %% [markdown]
# Now we're ready to fit the model. This requires the use of CountVecorizer, which we've already used, and the scikit-learn function LatentDirichletAllocation.
#
# See [here](http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html) for more information about this function.

# %%
import time
start_time = time.time()

#should switch to batch (from online).  n_samples should be closer to full set

####Adopted From: 
#Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

n_samples = 2000
n_topics = 5
n_top_words = 50

##This is a function to print out the top words for each topic in a pretty way.
#Don't worry too much about understanding every line of this code.
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# Use tf-idf features
tfidf_vectorizer = TfidfVectorizer(max_df=0.80, min_df=50,
                                   max_features=None,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(df_lit['PS1'])

# Use tf (raw term count) features
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.80, min_df=50,
                                max_features=None,
                                stop_words='english'
                                )

tf = tf_vectorizer.fit_transform(df_lit['PS1'])

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_topics=%d..."
      % (n_samples, n_topics))

#define the lda function, with desired options TAKE A LOOK AT THIS.  MIGHT BE TOO FEW
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=20,  #100 (THATS WHAT LAURA DID)
                                learning_method='online',  # CHANGE THIS TO BATCH
                                learning_offset=80.,
                                total_samples=n_samples, # TAKE A LOOK AT THIS RE CHANGE TO BATCH
                                random_state=0)
#fit the model
lda.fit(tf)

#print the top words per topic, using the function defined above.
#Unlike R, which has a built-in function to print top words, we have to write our own for scikit-learn
#I think this demonstrates the different aims of the two packages: R is for social scientists, Python for computer scientists

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)

print("This program took", time.time() - start_time, "seconds to run.")
# Out:
# Extracting tf features for LDA...
# Fitting LDA models with tf features, n_samples=2000 and n_topics=5...
#
# Topics in LDA model:
#
# Topic #0:
# science world computer engineering math knowledge school technology research work new passion like business time learning learn field problems physics create father art study future learned use engineer make high curiosity design class chemistry love problem biology project experience different programming mathematics career books pursue way interests things skills working
#
# Topic #1:
# family life parents school mother want work father help people hard time make education college mom like did able years know dad world better person future things way high best day come brother home just wanted dreams going dream taught sister learned support live good career ve working didn year
#
# Topic #2:
# school high students year team community class time music friends new student people club years life learned grade work group classes best experience program like activities teacher teachers skills play helped sports taught make just day ve playing leadership did started felt help college academic able began passion different middle
#
# Topic #3:
# world people family different community culture life new american city cultures country school chinese language parents education society experiences years experience cultural living come social live china like english environment change home america born place history united international learn small friends values way town diverse believe understand countries learned want
#
# Topic #4:
# like time day life just world people home felt know years did way mother old room little love didn away eyes new mom dad family began make night feel thought year house words friends long saw ve want left came knew father remember mind face don told realized said look
#
# This program took 1837.9760208129883 seconds to run.

# %%
####Exercise:
###Run the same code as above but change some of the parameters. How does this change the output.
###Suggestions:
## 0. Use tf-idf scores rather than raw counts. (hint: look for the variable name we created) 
## 1. Change the number of topics. What do you find?
## 2. Do not remove stop words. How does this change the output?

# %% [markdown]
# One thing we may want to do with the output is find the most representative texts for each topic. A simple way to do this (but not memory efficient), is to merge the topic distribution back into the Pandas dataframe.
#
# First get the topic distribution array.

# %%
topic_dist = lda.transform(tf)
topic_dist
# Out:
# array([[   0.20343325,    0.20504045,    0.20497347,  110.28843997,
#          139.09811286],
#        [ 109.96753759,   30.80927003,   11.87385879,   21.3098719 ,
#           83.03946168],
#        [  41.44346225,    0.20524765,   70.8687638 ,   46.7489046 ,
#           62.7336217 ],
#        ...,
#        [   4.32063697,    0.20647573,   98.60036012,    0.20334955,
#           69.66917763],
#        [   0.20494707,   18.87963714,   50.58311541,   74.04510118,
#           42.2871992 ],
#        [   0.20368881,    0.20459388,    8.71260145,   70.13343541,
#          116.74568044]])

# %% [markdown]
# Merge back in with the original dataframe.

# %%
topic_dist_df = pandas.DataFrame(topic_dist)
df_w_topics = topic_dist_df.join(df_lit)
df_w_topics
# Out:
#                 0           1           2           3           4       CPID  \
# 0        0.203433    0.205040    0.204973  110.288440  139.098113  3128896.0
# 1      109.967538   30.809270   11.873859   21.309872   83.039462  3092833.0
# 2       41.443462    0.205248   70.868764   46.748905   62.733622  3142974.0
# 3        0.202537   52.873869   31.534691   59.120310   46.268593  3020517.0
# 4       10.124690   53.875667   33.511001   27.281887    0.206755  3121294.0
# 5        0.206644    6.189918   25.058109  141.975725   65.569604  3162551.0
# 6       11.736947  138.640419    0.204997    0.209768   65.207869  3090215.0
# 7      117.207170    0.206436   57.122360   35.257507    0.206528  3158702.0
# 8        6.245896   90.026427   57.320493    0.203186    0.203998  3095465.0
# 9       60.436144   58.569313    0.204069    0.206332   49.584141  3147750.0
# 10       0.206373   30.319225   30.635792    5.256093   69.582517  3036137.0
# 11      13.659156   16.060659   14.259235   31.899344   30.121606  3141678.0
# 12      25.326745    0.204431   49.312810   24.895168  154.260846  3162364.0
# 13       0.203501   40.171433   93.341251   40.078748    0.205068  3123069.0
# 14       0.204032   11.185850  142.056527    8.347878    0.205713  3079536.0
# 15       0.204324   95.043255   88.966823   51.328940   30.456657  3016488.0
# 16       3.532234   83.406208   62.125766   54.728434    0.207359  3137797.0
# 17     121.293918    0.204872    0.204937    0.202655   85.093619  3056976.0
# 18       0.206680  189.130012   22.469941    0.206437   20.986931  3095466.0
# 19      32.748067   22.665990    8.312654    0.204750   67.068540  3138338.0
# 20       2.648072    0.205675   58.587868   30.330118  108.228267  3056175.0
# 21     113.274668   74.227357    0.204239    0.205648   41.088088  3097991.0
# 22       6.506350   61.359716    0.206509   91.037057   55.890368  3103507.0
# 23      35.540880   83.901050    0.204663   43.581580   16.771827  3140004.0
# 24       9.821773   21.166279   71.687861   18.120124    0.203963  3003517.0
# 25       0.203593  125.608391    0.204963    8.747604   19.235449  3121783.0
# 26       0.206050  177.480580   43.364309   40.742746    0.206315  3023027.0
# 27     112.651045   33.736533   11.969069   17.440610    0.202743  3124456.0
# 28      29.151264    0.204870   17.037977   49.147307  140.458582  3080657.0
# 29       0.204085   29.392249    0.203329   81.717277   54.483061  3129963.0
# ...           ...         ...         ...         ...         ...        ...
# 82504   75.374590    0.205527   18.817478  138.920271   50.682135  3044465.0
# 82505  232.945861   22.672353    0.203906    0.206658   13.971221  3133579.0
# 82506  136.422575   52.555930   30.608566    0.206452    0.206477  3098421.0
# 82507  128.986377   11.352192   38.130183    7.327830    0.203418  3051780.0
# 82508   16.657812    0.206431   44.035583   90.206649   84.893525  3081688.0
# 82509  115.131947   89.206254    8.297970    0.206555   44.157275  3158611.0
# 82510   76.447011   18.321056   86.508415    0.203458   35.520060  3110512.0
# 82511    0.203097   44.650687    0.204605    2.509049  113.432562  3124347.0
# 82512   67.601380  121.318291   19.572606    0.205777   39.301946  3004871.0
# 82513    0.204588    0.207004  121.178681    0.204958    0.204768  3016272.0
# 82514   17.234614   21.142199   25.160381   82.659198   70.803608  3030537.0
# 82515   12.481443   45.718733    0.205766  106.387848    0.206210  3114336.0
# 82516    0.204349   88.593772    9.791936    0.205221    0.204722  3008209.0
# 82517    2.696207  108.788467    0.203543   10.655984   77.655799  3010793.0
# 82518   36.968947   60.974339   31.417391   52.179706   38.459617  3012294.0
# 82519   75.729183   20.075716    0.206897   21.102337   45.885867  3081109.0
# 82520    0.203700  233.629769    0.205088    0.204193   26.757250  3058242.0
# 82521   34.366154    0.205594   27.789609   89.340551   60.298091  3113833.0
# 82522   15.437834    0.203654  105.111237   42.741738   45.505538  3095238.0
# 82523   12.422663    7.195903   45.345385   18.828934    0.207115  3105037.0
# 82524   16.766340   67.028964   41.929489   50.067581    0.207625  3044794.0
# 82525    0.204600  103.652096   25.369518   65.374387   59.399399  3094845.0
# 82526   17.984846   18.517167   99.642660   29.649597    0.205729  3007697.0
# 82527   83.254468    0.204677   14.231678   78.104846    0.204330  3094653.0
# 82528    0.206506    0.206109    0.206044   91.611601  175.769740  3092077.0
# 82529    0.205933   47.543060    0.203874    0.205951  115.841183  3031930.0
# 82530    0.203855   12.311656  120.072033    0.208622    0.203835  3143242.0
# 82531    4.320637    0.206476   98.600360    0.203350   69.669178  3000721.0
# 82532    0.204947   18.879637   50.583115   74.045101   42.287199  3093718.0
# 82533    0.203689    0.204594    8.712601   70.133435  116.745680  3029032.0
#
#                                College  \
# 0       College of Letters and Science
# 1               College of Engineering
# 2               College of Engineering
# 3       College of Letters and Science
# 4         College of Natural Resources
# 5       College of Letters and Science
# 6       College of Letters and Science
# 7               College of Engineering
# 8         College of Natural Resources
# 9       College of Letters and Science
# 10      College of Letters and Science
# 11      College of Letters and Science
# 12      College of Letters and Science
# 13        College of Natural Resources
# 14      College of Letters and Science
# 15      College of Letters and Science
# 16              College of Engineering
# 17              College of Engineering
# 18      College of Letters and Science
# 19      College of Letters and Science
# 20              College of Engineering
# 21              College of Engineering
# 22                College of Chemistry
# 23      College of Letters and Science
# 24      College of Letters and Science
# 25      College of Letters and Science
# 26      College of Letters and Science
# 27      College of Letters and Science
# 28      College of Letters and Science
# 29        College of Natural Resources
# ...                                ...
# 82504   College of Letters and Science
# 82505   College of Letters and Science
# 82506   College of Letters and Science
# 82507   College of Letters and Science
# 82508   College of Letters and Science
# 82509   College of Letters and Science
# 82510           College of Engineering
# 82511   College of Letters and Science
# 82512     College of Natural Resources
# 82513   College of Letters and Science
# 82514           College of Engineering
# 82515   College of Letters and Science
# 82516   College of Letters and Science
# 82517           College of Engineering
# 82518           College of Engineering
# 82519           College of Engineering
# 82520  College of Environmental Design
# 82521     College of Natural Resources
# 82522   College of Letters and Science
# 82523   College of Letters and Science
# 82524           College of Engineering
# 82525           College of Engineering
# 82526   College of Letters and Science
# 82527   College of Letters and Science
# 82528           College of Engineering
# 82529             College of Chemistry
# 82530           College of Engineering
# 82531           College of Engineering
# 82532   College of Letters and Science
# 82533   College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a ' ", lean man, who loo...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82504  I come from a very conservative and traditiona...
# 82505  In a world that's dominated by news headlines ...
# 82506  The world I grew up in nurtured my aspirations...
# 82507  When I was three years old, my parents dragged...
# 82508  In the melting pot of America, I am expected t...
# 82509  One thing I do not have in common with my fami...
# 82510  Being the youngest of five brothers is somethi...
# 82511  The "world" I come from is not a world in the ...
# 82512  I can't remember the first time I realized tha...
# 82513  "Daddy, look at the aoplane!" While my other f...
# 82514  I have always wanted to build a computer. I sp...
# 82515  As a two-year-old, I came home from pre-school...
# 82516  I have always been interested in science. The ...
# 82517  When food arrives at our table, my friends rea...
# 82518  I first enjoyed computer programming in fifth ...
# 82519  Berkeley is well known as a very open and dive...
# 82520  It's a cold Monday morning as I shut the passe...
# 82521  My first kiss was a sea cucumber. When a Sea W...
# 82522  It was : in the morning and I was bored. My ba...
# 82523  I grew up on an island. Piedmont, that is, an ...
# 82524  ?My environment has always been isolation with...
# 82525  ?Thoughts bustle through my mind, as I stand o...
# 82526  I grew up in the slums of Lodi, California, wh...
# 82527  "Your support is the only reason I'm alive." A...
# 82528  My mom wanted to be an engineer.\\After she ea...
# 82529  My parents always told me to stay away from ho...
# 82530  My life has been much different than most kids...
# 82531  My name is Edrian Zulueta. I was born in the P...
# 82532  Tsungiriro\The saying "It takes a village to r...
# 82533  I come from a broken family. My parents were n...
#
#                                                      PS2
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82504  "Free Free Palestine, Long Live Palestine!" Th...
# 82505  Determination and dedication are the key ingre...
# 82506  Playing professional soccer, a boy's dream sin...
# 82507  There are a variety of summer debate camps and...
# 82508  In the agricultural community I live in, it wa...
# 82509  I've always felt different.  From the American...
# 82510  Throughout my life I've been taught of the unr...
# 82511  As a child, I often envisioned what it would b...
# 82512  I've never been a fan of the cramped dressing ...
# 82513  I start a beat with the high hat cymbal with m...
# 82514  Knowledge is power. It's a saying that is alwa...
# 82515  Knitting. Not my normal Sunday morning.  My te...
# 82516  Since Middle School, I have been taking cerami...
# 82517  There is something special about the feeling I...
# 82518  I began to fence at fourteen and since then it...
# 82519  Music is important to me as an escape and a wa...
# 82520  On a cold Christmas morning, when the windows ...
# 82521  I consider myself an original person, though o...
# 82522  My career in journalism started freshmen year ...
# 82523  ?I didn't say a thing on the drive home from t...
# 82524  ?Whenever I tell this story to any human willi...
# 82525  ?Sharing pictures is like inviting other peopl...
# 82526  Peace settles in my heart at the sound of the ...
# 82527  1+1=2. Yet so is 1*2. Mathematics has not only...
# 82528  I can't speak Mandarin but I somehow ended up ...
# 82529  "How are you going to do the literature essays...
# 82530  My social abilities are what set me apart from...
# 82531  I'm a very nice and understanding person, I'm ...
# 82532  Loving My Skin\It seems too presumptuous to co...
# 82533  "Must've been a mainland Chinese," my teacher ...
#
# [82534 rows x 9 columns]

# %%
df_w_topics.columns = ['T0_PS1', 'T1_PS1', 'T2_PS1', 'T2_PS1', 'T4_PS1', 'CPID', 'College', 'PS1', 'PS2']
df_w_topics
# Out:
#            T0_PS1      T1_PS1      T2_PS1      T2_PS1      T4_PS1       CPID  \
# 0        0.203433    0.205040    0.204973  110.288440  139.098113  3128896.0
# 1      109.967538   30.809270   11.873859   21.309872   83.039462  3092833.0
# 2       41.443462    0.205248   70.868764   46.748905   62.733622  3142974.0
# 3        0.202537   52.873869   31.534691   59.120310   46.268593  3020517.0
# 4       10.124690   53.875667   33.511001   27.281887    0.206755  3121294.0
# 5        0.206644    6.189918   25.058109  141.975725   65.569604  3162551.0
# 6       11.736947  138.640419    0.204997    0.209768   65.207869  3090215.0
# 7      117.207170    0.206436   57.122360   35.257507    0.206528  3158702.0
# 8        6.245896   90.026427   57.320493    0.203186    0.203998  3095465.0
# 9       60.436144   58.569313    0.204069    0.206332   49.584141  3147750.0
# 10       0.206373   30.319225   30.635792    5.256093   69.582517  3036137.0
# 11      13.659156   16.060659   14.259235   31.899344   30.121606  3141678.0
# 12      25.326745    0.204431   49.312810   24.895168  154.260846  3162364.0
# 13       0.203501   40.171433   93.341251   40.078748    0.205068  3123069.0
# 14       0.204032   11.185850  142.056527    8.347878    0.205713  3079536.0
# 15       0.204324   95.043255   88.966823   51.328940   30.456657  3016488.0
# 16       3.532234   83.406208   62.125766   54.728434    0.207359  3137797.0
# 17     121.293918    0.204872    0.204937    0.202655   85.093619  3056976.0
# 18       0.206680  189.130012   22.469941    0.206437   20.986931  3095466.0
# 19      32.748067   22.665990    8.312654    0.204750   67.068540  3138338.0
# 20       2.648072    0.205675   58.587868   30.330118  108.228267  3056175.0
# 21     113.274668   74.227357    0.204239    0.205648   41.088088  3097991.0
# 22       6.506350   61.359716    0.206509   91.037057   55.890368  3103507.0
# 23      35.540880   83.901050    0.204663   43.581580   16.771827  3140004.0
# 24       9.821773   21.166279   71.687861   18.120124    0.203963  3003517.0
# 25       0.203593  125.608391    0.204963    8.747604   19.235449  3121783.0
# 26       0.206050  177.480580   43.364309   40.742746    0.206315  3023027.0
# 27     112.651045   33.736533   11.969069   17.440610    0.202743  3124456.0
# 28      29.151264    0.204870   17.037977   49.147307  140.458582  3080657.0
# 29       0.204085   29.392249    0.203329   81.717277   54.483061  3129963.0
# ...           ...         ...         ...         ...         ...        ...
# 82504   75.374590    0.205527   18.817478  138.920271   50.682135  3044465.0
# 82505  232.945861   22.672353    0.203906    0.206658   13.971221  3133579.0
# 82506  136.422575   52.555930   30.608566    0.206452    0.206477  3098421.0
# 82507  128.986377   11.352192   38.130183    7.327830    0.203418  3051780.0
# 82508   16.657812    0.206431   44.035583   90.206649   84.893525  3081688.0
# 82509  115.131947   89.206254    8.297970    0.206555   44.157275  3158611.0
# 82510   76.447011   18.321056   86.508415    0.203458   35.520060  3110512.0
# 82511    0.203097   44.650687    0.204605    2.509049  113.432562  3124347.0
# 82512   67.601380  121.318291   19.572606    0.205777   39.301946  3004871.0
# 82513    0.204588    0.207004  121.178681    0.204958    0.204768  3016272.0
# 82514   17.234614   21.142199   25.160381   82.659198   70.803608  3030537.0
# 82515   12.481443   45.718733    0.205766  106.387848    0.206210  3114336.0
# 82516    0.204349   88.593772    9.791936    0.205221    0.204722  3008209.0
# 82517    2.696207  108.788467    0.203543   10.655984   77.655799  3010793.0
# 82518   36.968947   60.974339   31.417391   52.179706   38.459617  3012294.0
# 82519   75.729183   20.075716    0.206897   21.102337   45.885867  3081109.0
# 82520    0.203700  233.629769    0.205088    0.204193   26.757250  3058242.0
# 82521   34.366154    0.205594   27.789609   89.340551   60.298091  3113833.0
# 82522   15.437834    0.203654  105.111237   42.741738   45.505538  3095238.0
# 82523   12.422663    7.195903   45.345385   18.828934    0.207115  3105037.0
# 82524   16.766340   67.028964   41.929489   50.067581    0.207625  3044794.0
# 82525    0.204600  103.652096   25.369518   65.374387   59.399399  3094845.0
# 82526   17.984846   18.517167   99.642660   29.649597    0.205729  3007697.0
# 82527   83.254468    0.204677   14.231678   78.104846    0.204330  3094653.0
# 82528    0.206506    0.206109    0.206044   91.611601  175.769740  3092077.0
# 82529    0.205933   47.543060    0.203874    0.205951  115.841183  3031930.0
# 82530    0.203855   12.311656  120.072033    0.208622    0.203835  3143242.0
# 82531    4.320637    0.206476   98.600360    0.203350   69.669178  3000721.0
# 82532    0.204947   18.879637   50.583115   74.045101   42.287199  3093718.0
# 82533    0.203689    0.204594    8.712601   70.133435  116.745680  3029032.0
#
#                                College  \
# 0       College of Letters and Science
# 1               College of Engineering
# 2               College of Engineering
# 3       College of Letters and Science
# 4         College of Natural Resources
# 5       College of Letters and Science
# 6       College of Letters and Science
# 7               College of Engineering
# 8         College of Natural Resources
# 9       College of Letters and Science
# 10      College of Letters and Science
# 11      College of Letters and Science
# 12      College of Letters and Science
# 13        College of Natural Resources
# 14      College of Letters and Science
# 15      College of Letters and Science
# 16              College of Engineering
# 17              College of Engineering
# 18      College of Letters and Science
# 19      College of Letters and Science
# 20              College of Engineering
# 21              College of Engineering
# 22                College of Chemistry
# 23      College of Letters and Science
# 24      College of Letters and Science
# 25      College of Letters and Science
# 26      College of Letters and Science
# 27      College of Letters and Science
# 28      College of Letters and Science
# 29        College of Natural Resources
# ...                                ...
# 82504   College of Letters and Science
# 82505   College of Letters and Science
# 82506   College of Letters and Science
# 82507   College of Letters and Science
# 82508   College of Letters and Science
# 82509   College of Letters and Science
# 82510           College of Engineering
# 82511   College of Letters and Science
# 82512     College of Natural Resources
# 82513   College of Letters and Science
# 82514           College of Engineering
# 82515   College of Letters and Science
# 82516   College of Letters and Science
# 82517           College of Engineering
# 82518           College of Engineering
# 82519           College of Engineering
# 82520  College of Environmental Design
# 82521     College of Natural Resources
# 82522   College of Letters and Science
# 82523   College of Letters and Science
# 82524           College of Engineering
# 82525           College of Engineering
# 82526   College of Letters and Science
# 82527   College of Letters and Science
# 82528           College of Engineering
# 82529             College of Chemistry
# 82530           College of Engineering
# 82531           College of Engineering
# 82532   College of Letters and Science
# 82533   College of Letters and Science
#
#                                                      PS1  \
# 0      Bojio!\\That was what I playfully typed on my ...
# 1      My world is shaped by a ' ", lean man, who loo...
# 2      I come from a mediocre family in Malaysia. As ...
# 3      Being a Mexican-American now is one of the mos...
# 4      I am really confused when I have to fill out i...
# 5      Since before I was born, my parents wanted me ...
# 6      When I think of my cousin Sid, I see him as th...
# 7      I was born in a suburb just east of Seattle, t...
# 8      Being the youngest in my family, I have been h...
# 9      Living up to the grand expectations of a cardi...
# 10     I have never once seen my parents watch a spor...
# 11     Above all else my family is adventurous. They ...
# 12     ?Paper shuffles, the hum of the engine is hear...
# 13     My name is Giovanni Aawar, I'm American Lebane...
# 14     Growing up in a household with my parents and ...
# 15     Living in the impoverished Arlington Heights, ...
# 16     Brought into this world by two Ethiopian natio...
# 17     For as long as I can remember, I've been a tin...
# 18     I have come to value hardships in life, as the...
# 19     I come from a world of glitter, feathers, and ...
# 20     I sat in the dining room, watching the chaotic...
# 21     My childhood was far from normal. Imagine some...
# 22     This isn't what I expected at all. It's a conv...
# 23     Our aspirations are shaped by our environment ...
# 24     Squad. My squad is my pride of lions, and we a...
# 25     Having grown up in an Ethiopian home, my paren...
# 26     I live in an environment so free of barriers t...
# 27     Growing up, I was greatly influenced by my par...
# 28     I would be lying if I said that moving to Amer...
# 29     To describe the world I come from, I would nee...
# ...                                                  ...
# 82504  I come from a very conservative and traditiona...
# 82505  In a world that's dominated by news headlines ...
# 82506  The world I grew up in nurtured my aspirations...
# 82507  When I was three years old, my parents dragged...
# 82508  In the melting pot of America, I am expected t...
# 82509  One thing I do not have in common with my fami...
# 82510  Being the youngest of five brothers is somethi...
# 82511  The "world" I come from is not a world in the ...
# 82512  I can't remember the first time I realized tha...
# 82513  "Daddy, look at the aoplane!" While my other f...
# 82514  I have always wanted to build a computer. I sp...
# 82515  As a two-year-old, I came home from pre-school...
# 82516  I have always been interested in science. The ...
# 82517  When food arrives at our table, my friends rea...
# 82518  I first enjoyed computer programming in fifth ...
# 82519  Berkeley is well known as a very open and dive...
# 82520  It's a cold Monday morning as I shut the passe...
# 82521  My first kiss was a sea cucumber. When a Sea W...
# 82522  It was : in the morning and I was bored. My ba...
# 82523  I grew up on an island. Piedmont, that is, an ...
# 82524  ?My environment has always been isolation with...
# 82525  ?Thoughts bustle through my mind, as I stand o...
# 82526  I grew up in the slums of Lodi, California, wh...
# 82527  "Your support is the only reason I'm alive." A...
# 82528  My mom wanted to be an engineer.\\After she ea...
# 82529  My parents always told me to stay away from ho...
# 82530  My life has been much different than most kids...
# 82531  My name is Edrian Zulueta. I was born in the P...
# 82532  Tsungiriro\The saying "It takes a village to r...
# 82533  I come from a broken family. My parents were n...
#
#                                                      PS2
# 0      Costume: a torn and tattered shirt and pants s...
# 1      Since childhood, I have yearned for utopia. I ...
# 2      I was raised in a family where academics was t...
# 3      I learned about the female stereotypes early i...
# 4      The bus was loud and smelled. It did not help ...
# 5      In the past, when I wanted information and ins...
# 6      There's a reason that people buy magazines: th...
# 7      I've had a few defining moments throughout my ...
# 8      One talent that I am proud to have is dancing,...
# 9      Throughout my life, I've explored, enjoyed, an...
# 10     From the ages of six to eight I kept a journal...
# 11     One experience that remains exceptionally impo...
# 12     ?My high school experience has been shaped mos...
# 13     Selecting a profession is a personal decision ...
# 14     On every second day of the academic year, my s...
# 15     At the beginning of eighth grade , I woke up o...
# 16     I began playing soccer at the age of 5, for sm...
# 17     As a shy 9th grade student, I was reluctant to...
# 18     Jumping off an airplane, swimming with sharks,...
# 19     I am not the type of person one usually finds ...
# 20     "Allyson has just won King of the Lab!" my che...
# 21     Stepping inside my mind leads to a talent that...
# 22     It is a decision that forever changed my ident...
# 23     I knocked on the door. I had recently attended...
# 24     "What's an intangible?"\Improving. The ability...
# 25     A couple years ago, I got in an argument with ...
# 26     Through school and my participation in my comm...
# 27     It was a cool summer day, and my eccentric 13-...
# 28     An activity I've been involved in since the 8t...
# 29     "The place where dreams come true," that is th...
# ...                                                  ...
# 82504  "Free Free Palestine, Long Live Palestine!" Th...
# 82505  Determination and dedication are the key ingre...
# 82506  Playing professional soccer, a boy's dream sin...
# 82507  There are a variety of summer debate camps and...
# 82508  In the agricultural community I live in, it wa...
# 82509  I've always felt different.  From the American...
# 82510  Throughout my life I've been taught of the unr...
# 82511  As a child, I often envisioned what it would b...
# 82512  I've never been a fan of the cramped dressing ...
# 82513  I start a beat with the high hat cymbal with m...
# 82514  Knowledge is power. It's a saying that is alwa...
# 82515  Knitting. Not my normal Sunday morning.  My te...
# 82516  Since Middle School, I have been taking cerami...
# 82517  There is something special about the feeling I...
# 82518  I began to fence at fourteen and since then it...
# 82519  Music is important to me as an escape and a wa...
# 82520  On a cold Christmas morning, when the windows ...
# 82521  I consider myself an original person, though o...
# 82522  My career in journalism started freshmen year ...
# 82523  ?I didn't say a thing on the drive home from t...
# 82524  ?Whenever I tell this story to any human willi...
# 82525  ?Sharing pictures is like inviting other peopl...
# 82526  Peace settles in my heart at the sound of the ...
# 82527  1+1=2. Yet so is 1*2. Mathematics has not only...
# 82528  I can't speak Mandarin but I somehow ended up ...
# 82529  "How are you going to do the literature essays...
# 82530  My social abilities are what set me apart from...
# 82531  I'm a very nice and understanding person, I'm ...
# 82532  Loving My Skin\It seems too presumptuous to co...
# 82533  "Must've been a mainland Chinese," my teacher ...
#
# [82534 rows x 9 columns]

# %%
df_w_topics.to_csv('Admissions_PS1_Full_Output.csv', sep=',')

# %% [markdown]
# Now we can sort the dataframe for the topic of interest, and view the top documents for the topics.
# Below we sort the documents first by Topic 0 (looking at the top words for this topic I think it's about family, health, and domestic activities), and next by Topic 1 (again looking at the top words I think this topic is about children playing outside in nature). These topics may be a family/nature split?
#
# Look at the titles for the two different topics. Look at the gender of the author. Hypotheses?

# %%
print(df_w_topics[['ID', 'PS1', 0]].sort_values(by=[0], ascending=False))

# %% [markdown]
# We can read individual essays in full using the code below.  Change the number in the final set of brackets to point to a spesific serial number (ID-1).

# %%
df['PS1'][1980]

# %%
print(df_w_topics[['ID', 'PS1', 1]].sort_values(by=[1], ascending=False))

# %%
df['PS1'][2131]

# %%
print(df_w_topics[['ID', 'PS1', 2]].sort_values(by=[2], ascending=False))

# %%
df['PS1'][3515]

# %%
print(df_w_topics[['ID', 'PS1', 3]].sort_values(by=[3], ascending=False))

# %%
df['PS1'][2645]

# %%
print(df_w_topics[['ID', 'PS1', 4]].sort_values(by=[4], ascending=False))

# %%
df['PS1'][811]

# %% [markdown]
# What other patterns might we find with topic modeling? Toward what end?

# %%
###Ex (gold star exercise!): 
#       Find the most prevalent topic in the corpus.
#       Find the least prevalent topic in the corpus. 
#       Find the most prevalent topic by the gender of the author.
#       Hint: How do we define prevalence? What are different ways of measuring this,
#              and the benefits/drawbacks of each.


#       Extra bonus gold star exercise:
#          This topic model provide the topic distribtution for 127 rows, but there are 131 rows in the full data.
#          What is going on here? (I don't have an answer to this. I hope someone can figure it out!)
