# %% [markdown]
# # Manipulating Topic Model Output

# %% [markdown]
# This script can import the output of a scikit_learn LDA topic model to interpret the result.

# %% [markdown]
# ## 0. Import Pacakges and Initilize Variables

# %% [markdown]
# This gets us started.

# %%
import pandas
import numpy
print('All packages successfully imported!')
# Out:
# All packages successfully imported!

# %% [markdown]
# ## 1. Import the Topic Model Output

# %%
doc_topic_df = pandas.read_csv("/Volumes/Extra Space/Google Drive/Scholarship/Writing Projects - Personal/Admissions Essays/Data/model output/Admissions_PS1_5_Topic_Date_2017-04-30_Time_14-09.csv", sep = ',', index_col=0, encoding = 'utf_8')
term_topic_df = pandas.read_csv("/Volumes/Extra Space/Google Drive/Scholarship/Writing Projects - Personal/Admissions Essays/Data/model output/Admissions_PS1_Feature_Words_5_Topic_Date_2017-04-30_Time_14-09.csv", sep = ',', index_col=0, encoding = 'utf_8')
print('Imported the Topic Model output.')
# Out:
# Imported the Topic Model output.

# %%
doc_topic_df
# Out:
#           CPID                         College  \
# 0      3128896  College of Letters and Science
# 1      3092833          College of Engineering
# 2      3142974          College of Engineering
# 3      3020517  College of Letters and Science
# 4      3121294    College of Natural Resources
# 5      3162551  College of Letters and Science
# 6      3090215  College of Letters and Science
# 7      3158702          College of Engineering
# 8      3095465    College of Natural Resources
# 9      3147750  College of Letters and Science
# 10     3036137  College of Letters and Science
# 11     3141678  College of Letters and Science
# 12     3162364  College of Letters and Science
# 13     3123069    College of Natural Resources
# 14     3079536  College of Letters and Science
# 15     3016488  College of Letters and Science
# 16     3137797          College of Engineering
# 17     3056976          College of Engineering
# 18     3095466  College of Letters and Science
# ...

# %%
term_topic_df
# Out:
#       Feature_Words  Topic_0_PS1_features  Topic_1_PS1_features  \
# 0                aa              0.206712             47.398354
# 1             aaron              0.205731             23.785461
# 2                ab              0.203282             51.098115
# 3             aback             18.604948              0.205440
# 4             abacu              0.203140              0.201921
# 5           abandon            243.534243            663.235849
# 6               abc              0.205937             14.080511
# 7           abdomen              0.214366              0.204643
# 8             abhor              0.204646              8.668204
# 9              abid             13.313924             50.996761
# 10             abil            953.696138           4148.415722
# 11           abject             73.180554              0.202559
# 12              abl           3586.931967          25274.240852
# 13           abnorm            142.100620             61.593851
# ...

# %%
#are there any missing values in the 
print(doc_topic_df.isnull().values.any())
#are there any missing values in the 
print(term_topic_df.isnull().values.any())
# Out:
# True
# False

# %%
#Find where the nan's are in the first dataframe
index0 = doc_topic_df['Topic_0_PS1'].index[doc_topic_df['Topic_0_PS1'].apply(numpy.isnan)]
index1 = doc_topic_df['Topic_1_PS1'].index[doc_topic_df['Topic_1_PS1'].apply(numpy.isnan)]
index2 = doc_topic_df['Topic_2_PS1'].index[doc_topic_df['Topic_2_PS1'].apply(numpy.isnan)]
index3 = doc_topic_df['Topic_3_PS1'].index[doc_topic_df['Topic_3_PS1'].apply(numpy.isnan)]
index4 = doc_topic_df['Topic_4_PS1'].index[doc_topic_df['Topic_3_PS1'].apply(numpy.isnan)]

df_index = doc_topic_df.index.values.tolist()
[df_index.index(i) for i in index0]
# Out:
# []

# %%
print(index0)
print(index1)
print(index2)
print(index3)
print(index4)
# Out:
# Int64Index([], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([], dtype='int64')

# %%
print(len(index1))
# Out:
# 40

# %%
doc_topic_df[pandas.isnull(doc_topic_df).any(axis=1)]
# Out:
#           CPID                          College  \
# 2695   3094431   College of Letters and Science
# 4460   3154717   College of Letters and Science
# 6851   3166277             College of Chemistry
# 14490  3084615   College of Letters and Science
# 18658  3111191   College of Letters and Science
# 30208  3119489   College of Letters and Science
# 63009  3108845   College of Letters and Science
# 66013  3158564   College of Letters and Science
# 72496  3029150  College of Environmental Design
# 75705  3067097   College of Letters and Science
# 82534  3089965   College of Letters and Science
# 82535  3094843   College of Letters and Science
# 82536  3114428           College of Engineering
# 82537  3047604           College of Engineering
# 82538  3085337     College of Natural Resources
# 82539  3158212           College of Engineering
# 82540  3132226   College of Letters and Science
# 82541  3133081   College of Letters and Science
# ...

# %%
doc_topic_df
post_processing_nan = (doc_topic_df['PS1'].str.len() < 10) ^ (doc_topic_df['PS2'].str.len() < 10) ^ (doc_topic_df['PS1_clean'].str.len() < 10) ^ (doc_topic_df['PS2_clean'].str.len() < 10)
doc_topic_df_short = doc_topic_df.loc[post_processing_nan]
doc_topic_df_short
# Out:
#           CPID                          College  \
# 2695   3094431   College of Letters and Science
# 4460   3154717   College of Letters and Science
# 6851   3166277             College of Chemistry
# 14490  3084615   College of Letters and Science
# 18658  3111191   College of Letters and Science
# 30208  3119489   College of Letters and Science
# 33437  3165372           College of Engineering
# 40726  3115474   College of Letters and Science
# 63009  3108845   College of Letters and Science
# 71580  3136537           College of Engineering
# 72496  3029150  College of Environmental Design
# 75705  3067097   College of Letters and Science
#
#                                                      PS1  \
# 2695   I became interested in Economics four years ag...
# 4460   I am horrible at making decisions. In the begi...
# 6851                                                   -
# 14490                                                  A
# ...
